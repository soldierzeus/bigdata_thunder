# %% [markdown]
# # 6.Data Collection with API

# %% [markdown]
# ## 6.1 Youtube
#
# site: https://console.developers.google.com/ <br>
# reference: https://developers.google.com/youtube/v3/docs?hl=ko <br>
#
# ```python
# from googleapiclient.discovery import build
# from googleapiclient.errors import HttpError
# from oauth2client.tools import argparser
#
# import pandas as pd
#
#
# DEVELOPER_KEY=''
# YOUTUBE_API_SERVICE_NAME='youtube'
# YOUTUBE_API_VERSION='v3'
#
# youtube = build(
#   YOUTUBE_API_SERVICE_NAME,
#   YOUTUBE_API_VERSION,
#   developerKey=DEVELOPER_KEY
#   )
# ```

# %% [markdown]
# ### Videos
#
# 채널 내 비디오 조회 기본 코드
# ```python
# response = (
#   youtube
#   .playlistItems()
#   .list(
#     playlistId=*channel_id*,
#     part='snippet',
#     maxResults=50
#     )
#   .execute()
#   )
# ```
#
#
# 1번의 query에 전체 데이터를 다 받을 수 없음 <br>
# 따라서 pageToken을 이용하여 다음 페이지의 정보를 받아야 함 <br>
# ```python
# if 'nextPageToken' in response:
#   response = (
#     youtube
#     .playlistItems()
#     .list(
#       playlistId=*channel_id*,
#       pageToken=response.get('nextPageToken'),
#       part='snippet',
#       maxResults=50
#       )
#     .execute()
#     )
# ```

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser

import pandas as pd


DEVELOPER_KEY='AIzaSyDitP67cnauWgzSvRqh0dbV9NAYMK6n5I4'
YOUTUBE_API_SERVICE_NAME='youtube'
YOUTUBE_API_VERSION='v3'

youtube = build(
  YOUTUBE_API_SERVICE_NAME,
  YOUTUBE_API_VERSION,
  developerKey=DEVELOPER_KEY
  )

# %%
response = (
    youtube
    .commentThreads()
    .list(
      part='snippet,replies', 
      videoId='uRFEhFIsyXY', 
      maxResults=100
      )
    .execute()
    )

# %%
response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'Xww8b_c8uFZmgPvo8iqdU2Brl0w',
#  'nextPageToken': 'QURTSl9pMlRMUVRrOXF6cV9iY0tYaWw1S29WOFJsZE1tTE1DSEE3Q2F5QXJyVUlfZzJJWmIzWGNZWk1TTXpXclo2c2FIdUxaRGVsN1JaQQ==',
#  'pageInfo': {'totalResults': 95, 'resultsPerPage': 100},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': '2p-YY6u4DamP2MGgqBnjjR1Y2rw',
#    'id': 'UgwUVviz4oNxi--lEJR4AaABAg',
#    'snippet': {'videoId': 'uRFEhFIsyXY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'FZrk8CeM4e-h_bWH8OsQ4oio9EY',
#      'id': 'UgwUVviz4oNxi--lEJR4AaABAg',
#      'snippet': {'videoId': 'uRFEhFIsyXY',
#       'textDisplay': '다음광고 혹시 실비김치??!!',
#       'textOriginal': '다음광고 혹시 실비김치??!!',
#       'authorDisplayName': '눈뽕국뽕짬뽕',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_Le2sLnMDMirmF9r7IzE0Bq1oi_o2Cc0v2SZP13leV4Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCN_t2YcEHzgo-uieYClUEQw',
# ...

# %% [markdown]
# # 찻 페이지 댓글 수집

# %%
# get함수는 딕셔너리 인덱스랑 또같다.
[response.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('textOriginal') for i in range(len(response.get('items')))]
# Out:
# ['다음광고 혹시 실비김치??!!',
#  '조회수가점점줄어드네',
#  '손석구 나오는꿈은 건드리면 반칙이지..',
#  '셀린디온ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '셀린 디온 ㅅㅂㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '엄지 티 셀린느 디온 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '손석구꿈꾸고있었댘ㅋㅇㅋㅋ\n로나 ㅋㅋㅋㅋ ㅋㅋㅋㅋ ㅋㅋㅋㅋ ㅋㅋㅋㅋ ㅋㅋㅋㅋ ㅋㅋㅋㅋ',
#  '지겨워',
#  '최고 입니다 ^^',
#  '또각또각ㅋㅋㅋㅋㅋㅋㅋ무슨 좀비오디션보는줄알앗네',
#  '안녕하십니까 하자마자 나가래 ㅋㅋㅋㅋㅋ',
#  '엄지님 티셔츠 셀린느 아니고 셀린디온 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 목늘어난것도 디테일이겠쥐,,',
#  '와 셀린 디온 킬포네',
#  '결혼 축하드려요!!!!',
#  '왜 엄지님한테서  원훈님 느낌이 많이나죠?ㅋ 커플은 닮는다더니  그래서 그런가??ㅋㅋㅋㅋ',
#  '세상에서 제일가는 포테이토칩ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '셀린 디온ㅋㅋㅋㅋㅋㅋㅋ',
#  '손석구 꿈ㅋ',
#  '와 아침에 연차내서 쉬는데 깨우는거 진짜 현실성미쳐쌎ㄷ',
#  '이 귀한걸.. 꼭꼭 씹어 먹겠습니다.',
#  '아 진짜 개웃겨ㅠㅠㅠㅠㅠㅠ',
#  '진세님 쿨톤인듯',
#  '엄지렐라 티셔츠가 셀린디온임',
#  '진세형 꺼져가 우주최강 찰짐ㅋㅋ',
#  '보고싶었어~',
#  '셀린느 디옹 티 ㅋㅋㅋㅋ \n저런건 어디서 구하시는거지 \n개터졌음',
#  'ㅋㅋㅋ엄지 진짜잠든거엿나 처음에 눈뜨는연기 짱이닼ㅋㅋㅋ',
#  '슬슬패턴의한계살짝느낌',
#  '중복 ㅋ',
#  '근데 숏박스 로고가,, 약간 영정사진같아여,,',
#  '잼있당ㅎㅎ',
#  '진세님 파랑색 넘 잘 어울림 ㅋㅋ',
#  '왜 이제는 둘이 진짜 닮은 것 같지',
#  '어디서  들어본야기같다요',
#  '찐남매는 이것도 환상이다…',
#  '광고 나오는데 설렌다',
#  '진세님 잘생경어요!!(본인은 남자)',
# ...

# %%
def get_comments_from_youtube_api_result(response):
    return [response.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('textOriginal') for i in range(len(response.get('items')))]

# %% [markdown]
# # 전체 댓글 수집

# %%
all_coments = []

response = (
      youtube
      .commentThreads()
      .list(
        part='snippet,replies', 
        videoId='uRFEhFIsyXY', 
        maxResults=100
      )
      .execute()
  )

all_coments.extend(get_comments_from_youtube_api_result(response))

while response.get('nextPageToken'):
  response = (
      youtube
      .commentThreads()
      .list(
        part='snippet,replies', 
        videoId='uRFEhFIsyXY', 
        maxResults=100,
        pageToken=response.get('nextPageToken')
      )
      .execute()
  )
  all_coments.extend(get_comments_from_youtube_api_result(response))
print(all_coments)
# Out:
# ['두 분이 이제는 점점 닮아보이기까지해요.', '참 재밌었는데..', '흥얼 ~', '말라리아에서 갑자기 터졌네 ㅋㅋㅋㅋ', '안녕하십니까ㅋㅋㅋㅋㅋㅋ하는 순간 바로 나가세요ㅋㅋㅋㅋㅋㅋㅋㅋ진짴ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ거의 우리언니.....', '3분순삭!!!', '신박하고 재미나던 숏박스 어디갓냐, 개씹노잼 되가내 구독자 거품되간다', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ미치겠따 진짜 하ㅜㅜㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '03:04 찐웃음인거 같은데 ㅋㅋㅋ', '실비김치 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '찐남매 컨텐츠 진세형 연애하는거도 찍어줘요ㅠㅠ', '처음에 asmr듣다가 잠든거 표현 대단티비', '나답글남기면로또당첨됌', '진짜 찐 남매라고해도 믿을듯…', '다음광고 혹시 실비김치??!!', '조회수가점점줄어드네', '손석구 나오는꿈은 건드리면 반칙이지..', '셀린디온ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '셀린 디온 ㅅㅂㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '엄지 티 셀린느 디온 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '손석구꿈꾸고있었댘ㅋㅇㅋㅋ\n로나 ㅋㅋㅋㅋ ㅋㅋㅋㅋ ㅋㅋㅋㅋ ㅋㅋㅋㅋ ㅋㅋㅋㅋ ㅋㅋㅋㅋ', '지겨워', '최고 입니다 ^^', '또각또각ㅋㅋㅋㅋㅋㅋㅋ무슨 좀비오디션보는줄알앗네', '안녕하십니까 하자마자 나가래 ㅋㅋㅋㅋㅋ', '엄지님 티셔츠 셀린느 아니고 셀린디온 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 목늘어난것도 디테일이겠쥐,,', '와 셀린 디온 킬포네', '결혼 축하드려요!!!!', '왜 엄지님한테서  원훈님 느낌이 많이나죠?ㅋ 커플은 닮는다더니  그래서 그런가??ㅋㅋㅋㅋ', '세상에서 제일가는 포테이토칩ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '셀린 디온ㅋㅋㅋㅋㅋㅋㅋ', '손석구 꿈ㅋ', '와 아침에 연차내서 쉬는데 깨우는거 진짜 현실성미쳐쌎ㄷ', '이 귀한걸.. 꼭꼭 씹어 먹겠습니다.', '아 진짜 개웃겨ㅠㅠㅠㅠㅠㅠ', '진세님 쿨톤인듯', '엄지렐라 티셔츠가 셀린디온임', '진세형 꺼져가 
# ...

# %%
len(all_coments)
# Out:
# 1225

# %%
for i in range(len(response.get('items'))):
    if response.get('items')[17].get('replies') :
        print(i)
        break

# %%
response.get('items')[17].get('replies').get('comments')
# Out:
# [{'kind': 'youtube#comment',
#   'etag': 'E44mzrOg_ngCJ_OCCWgIWlxG4Sg',
#   'id': 'UgzFO9ojOlL0LZh3QV54AaABAg.9fBO_9-SoQl9fCr3dfZ522',
#   'snippet': {'videoId': 'uRFEhFIsyXY',
#    'textDisplay': '@히루시야데루미 킹니프사ㄷㄷ',
#    'textOriginal': '@히루시야데루미 킹니프사ㄷㄷ',
#    'parentId': 'UgzFO9ojOlL0LZh3QV54AaABAg',
#    'authorDisplayName': 'ᄂᄀ',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu8Nvu7nwLdzZJCqT5nrquBrO80bdMWk67ouag=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/channel/UCjcXK-ulAJ2xlP03J0w7s5g',
#    'authorChannelId': {'value': 'UCjcXK-ulAJ2xlP03J0w7s5g'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2022-08-26T22:39:45Z',
#    'updatedAt': '2022-08-26T22:39:45Z'}},
#  {'kind': 'youtube#comment',
#   'etag': 'wxBGKirfy9O-EYiRqU0PxZV4YHA',
#   'id': 'UgzFO9ojOlL0LZh3QV54AaABAg.9fBO_9-SoQl9fBr1jeQEGv',
#   'snippet': {'videoId': 'uRFEhFIsyXY',
#    'textDisplay': '씹덕 프사는 뭐다?',
# ...

# %%
response = (
  youtube
  .search()
  .list(
    part='snippet',
    maxResults=50,
    channelId='UC1B6SalAoiJD7eHfMUA9QrA'
    )
  .execute()
  )

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'YUQu4XyinQYfrrxx2CrnBUwgO8g',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'KR',
#  'pageInfo': {'totalResults': 90, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'IZ_IVF1tbuaGkffSLJDcLPNbzvk',
#    'id': {'kind': 'youtube#video', 'videoId': 'lc0AXbBHJYc'},
#    'snippet': {'publishedAt': '2022-08-05T09:00:34Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '작전타임',
#     'description': '스케치코미디 #숏박스 #ufc.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lc0AXbBHJYc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lc0AXbBHJYc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lc0AXbBHJYc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
# ...

# %%
from operator import itemgetter


for i, item in enumerate(response.items()):
    if i == 5:
        video_info = item
        break

# %%
len(video_info)
# Out:
# 2

# %% [markdown]
# 1개 영상 제목

# %%
video_info[1][0].get('snippet').get('title')
# Out:
# '작전타임'

# %%
[video_info[1][i].get('snippet').get('title') for i in len(video_info[1])]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\user\Documents\github\bigdata_thunder\bigdata1\day07.ipynb 셀 21 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/github/bigdata_thunder/bigdata1/day07.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> [video_info[1][i].get('snippet').get('title') for i in len(video_info[1])]
#
# TypeError: 'int' object is not iterable

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'YUQu4XyinQYfrrxx2CrnBUwgO8g',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'KR',
#  'pageInfo': {'totalResults': 90, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'IZ_IVF1tbuaGkffSLJDcLPNbzvk',
#    'id': {'kind': 'youtube#video', 'videoId': 'lc0AXbBHJYc'},
#    'snippet': {'publishedAt': '2022-08-05T09:00:34Z',
#     'channelId': 'UC1B6SalAoiJD7eHfMUA9QrA',
#     'title': '작전타임',
#     'description': '스케치코미디 #숏박스 #ufc.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lc0AXbBHJYc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lc0AXbBHJYc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lc0AXbBHJYc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '숏박스',
#     'liveBroadcastContent': 'none',
# ...

# %%
response.get('items')[0].get('snippet').get('publishTime')
# Out:
# '2022-08-05T09:00:34Z'

# %%
response.get('items')[0].get('snippet').get('title')
# Out:
# '작전타임'

# %%
response.get('items')[0].get('snippet').get('channelId')
# Out:
# 'UC1B6SalAoiJD7eHfMUA9QrA'

# %%
[response.get('items')[i].get('snippet').get('publishTime') for i in range(50)]
# Out:
# ['2022-08-05T09:00:34Z',
#  '2022-04-16T09:00:00Z',
#  '2022-07-04T09:00:03Z',
#  '2022-01-20T03:15:00Z',
#  '2021-12-18T04:00:10Z',
#  '2022-06-01T09:00:04Z',
#  '2022-05-13T09:00:22Z',
#  '2022-04-08T09:00:22Z',
#  '2022-03-06T09:00:17Z',
#  '2022-03-29T09:00:21Z',
#  '2022-07-15T09:00:04Z',
#  '2022-01-27T09:00:32Z',
#  '2022-05-26T09:00:03Z',
#  '2022-04-28T09:00:22Z',
#  '2022-02-10T09:00:02Z',
#  '2022-04-21T09:00:10Z',
#  '2022-07-29T09:00:11Z',
#  '2022-07-01T09:00:16Z',
#  '2022-06-24T09:00:37Z',
#  '2022-06-10T09:00:14Z',
#  '2021-11-25T11:15:01Z',
#  '2022-03-18T09:00:21Z',
#  '2022-02-25T09:00:38Z',
#  '2021-12-12T03:48:43Z',
#  '2021-12-05T04:45:01Z',
#  '2022-01-02T06:16:24Z',
#  '2022-08-12T09:00:33Z',
#  '2021-11-17T09:30:01Z',
#  '2021-12-23T11:15:00Z',
#  '2022-02-20T09:00:16Z',
#  '2021-12-09T09:30:04Z',
#  '2022-03-03T09:00:11Z',
#  '2022-04-05T09:00:29Z',
#  '2021-10-30T05:00:08Z',
#  '2021-12-02T03:38:13Z',
#  '2021-11-13T03:42:43Z',
#  '2022-06-16T09:00:18Z',
# ...

# %%
[response.get('items')[i].get('snippet').get('title') for i in range(50)]
# Out:
# ['작전타임',
#  '벚꽃놀이',
#  '고깃집',
#  '대실',
#  '경차사러 갔다가 람보르기니 산 썰',
#  '병문안',
#  '특종',
#  '방송사고',
#  '여행계획',
#  '자가격리',
#  '메뉴 어떤 걸로 하시겠어요?',
#  '마감 30분 전',
#  '병문안',
#  '...',
#  '예쁜카페',
#  '홈트레이닝',
#  '은행',
#  '짜장면 내기',
#  '필요한 거 있으시면 말씀해주세요',
#  '상담',
#  '손흥민 어떡하냐',
#  '아프면 손 드세요',
#  '꺼져',
#  '1등 되면 얼마줄 거야?',
#  '모든 건 너한테 달렸어',
#  '내일 지구 멸망하면 뭐 할 거야?',
#  '제일 싼 집',
#  '얼마 할 거야?',
#  '군인 인 거 티나?',
#  '287번 101번',
#  '아이언맨 VS 헐크',
#  '대리니ㅁ 할말ㅇㅣ씁ㄴ다',
#  '살려주세요',
#  '말하지 말라고 (오겜 스포주의)',
#  '바퀴벌레 퇴치',
#  '누구지?',
#  '여자들',
#  '오빠 나 이러려고 만나?',
#  '너라면 어떻게 할거야?',
#  '컷',
#  '뭘 쳐다봐',
#  '유튜브 3일 차',
#  '니가 갔다와',
#  '신인배우',
#  '유튜브 30일 차',
#  '어디까지 얘기했지?',
#  '구독자 이벤트 뭐 하지?',
#  '구독자 이벤트 뭐 하지?',
#  '휴지 있으세요?',
#  '합석']

# %%
[response.get('items')[i].get('snippet').get('channelId') for i in range(50)]
# Out:
# ['UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
#  'UC1B6SalAoiJD7eHfMUA9QrA',
# ...

# %% [markdown]
# ### Comments
# 비디오 내 댓글 조회 기본 코드
# ```python
# response = (
#     youtube
#     .commentThreads()
#     .list(
#       part='snippet,replies',
#       videoId=*video_id*,
#       maxResults=100
#       )
#     .execute()
#     )
# ```
#
# 1번의 query에 전체 데이터를 다 받을 수 없음 <br>
# 따라서 pageToken을 이용하여 다음 페이지의 정보를 받아야 함 <br>
# ```python
# if 'nextPageToken' in response:
#   response = (
#     youtube
#     .commentThreads()
#     .list(
#       part='snippet,replies',
#       videoId=video_id,
#       pageToken=response.get('nextPageToken'),
#       maxResults=100
#       )
#     .execute()
#     )
# ```

# %%
pd.DataFrame({
    'date': [response.get('items')[i].get('snippet').get('publishTime') for i in range(50)],
    'title': [response.get('items')[i].get('snippet').get('title') for i in range(50)],
    'video_id': [response.get('items')[i].get('snippet').get('channelId') for i in range(50)]
})
# Out:
#                     date               title                  video_id
# 0   2022-08-05T09:00:34Z                작전타임  UC1B6SalAoiJD7eHfMUA9QrA
# 1   2022-04-16T09:00:00Z                벚꽃놀이  UC1B6SalAoiJD7eHfMUA9QrA
# 2   2022-07-04T09:00:03Z            고깃집  UC1B6SalAoiJD7eHfMUA9QrA
# 3   2022-01-20T03:15:00Z                  대실  UC1B6SalAoiJD7eHfMUA9QrA
# 4   2021-12-18T04:00:10Z  경차사러 갔다가 람보르기니 산 썰  UC1B6SalAoiJD7eHfMUA9QrA
# 5   2022-06-01T09:00:04Z           병문안  UC1B6SalAoiJD7eHfMUA9QrA
# 6   2022-05-13T09:00:22Z                  특종  UC1B6SalAoiJD7eHfMUA9QrA
# 7   2022-04-08T09:00:22Z                방송사고  UC1B6SalAoiJD7eHfMUA9QrA
# 8   2022-03-06T09:00:17Z                여행계획  UC1B6SalAoiJD7eHfMUA9QrA
# 9   2022-03-29T09:00:21Z                자가격리  UC1B6SalAoiJD7eHfMUA9QrA
# 10  2022-07-15T09:00:04Z     메뉴 어떤 걸로 하시겠어요?  UC1B6SalAoiJD7eHfMUA9QrA
# 11  2022-01-27T09:00:32Z            마감 30분 전  UC1B6SalAoiJD7eHfMUA9QrA
# ...

# %% [markdown]
# ## 6.2 Dart
#
# url에 key와 value값을 추가하여 호출
#
# site: https://opendart.fss.or.kr/ <br>
# reference: https://opendart.fss.or.kr/guide/main.do?apiGrpCd=DS001 <br>

# %%
import requests
import pandas as pd
from tqdm import tqdm

# %%
api_key = 'aad8902f062d010bc147854f95f914ff684f3092'

# %% [markdown]
# ### 공시정보
#
# ```python
# https://opendart.fss.or.kr/api/document.xml
# ```

# %% [markdown]
# ### 기업개황
#
# ```python
# https://opendart.fss.or.kr/api/company.json?crtfc_key=xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx&corp_code=00126380
# ```

# %% [markdown]
# ### 공시검색
#
# ```
# https://opendart.fss.or.kr/api/list.json?crtfc_key=xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx&bgn_de=20200117&end_de=20200117&corp_cls=Y&page_no=1&page_count=10
# ```

# %%
bgn_de = '20220601'
end_de = '20220831'

# %%
pblntf_ty = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
disclosures = []
for i in tqdm(range(1, 107)):
    disclosure_search = f'https://opendart.fss.or.kr/api/list.json?crtfc_key={api_key}&bgn_de={bgn_de}&end_de={end_de}&corp_cls=Y&page_no={i}&page_count=10'
    response = requests.get(disclosure_search)
    eval_response = eval(response.text).get('list')
    disclosures.extend(eval_response)
print(disclosures)
# Out:
# 100%|██████████| 106/106 [01:10<00:00,  1.51it/s]
# ...

# %%
pd.DataFrame(disclosures)
# Out:
#      corp_code corp_name stock_code corp_cls                  report_nm  \
# 0     00138242     쌍용자동차     003620        Y                     회생계획인가
# 1     00125974      삼부토건     001470        Y   [기재정정]주요사항보고서(전환사채권발행결정)
# 2     01180118   코람코더원리츠     417310        Y          주식등의대량보유상황보고서(약식)
# 3     00795135     코오롱인더     120110        Y  대규모기업집단현황공시[분기별공시(개별회사용)]
# 4     00120526      롯데쇼핑     023530        Y                증권신고서(채무증권)
# ...        ...       ...        ...      ...                        ...
# 1055  00158501       에스원     012750        Y          기업설명회(IR)개최(안내공시)
# 1056  00361008     HSD엔진     082740        Y        임원ㆍ주요주주특정증권등소유상황보고서
# 1057  00503668    LIG넥스원     079550        Y          기업설명회(IR)개최(안내공시)
# 1058  00401731      LG전자     066570        Y        임원ㆍ주요주주특정증권등소유상황보고서
# 1059  00152385     에이프로젠     007460        Y             조회공시요구(풍문또는보도)
#
#             rcept_no    flr_nm  rcept_dt rm
# 0     20220826800633     쌍용자동차  20220826  유
# ...

# %%
disclosure_search = f'https://opendart.fss.or.kr/api/list.json?crtfc_key={api_key}&bgn_de={bgn_de}&end_de={end_de}&corp_cls=Y&page_no=1&page_count=10&pblntf_ty=A'
response = requests.get(disclosure_search)
eval_response = eval(response.text)
eval_response.update[pblntf_ty]
# Out:
# {'status': '000',
#  'message': '정상',
#  'page_no': 1,
#  'page_count': 10,
#  'total_count': 960,
#  'total_page': 96,
#  'list': [{'corp_code': '00983040',
#    'corp_name': '한진칼',
#    'stock_code': '180640',
#    'corp_cls': 'Y',
#    'report_nm': '[기재정정]반기보고서 (2022.06)',
#    'rcept_no': '20220823000294',
#    'flr_nm': '한진칼',
#    'rcept_dt': '20220823',
#    'rm': ''},
#   {'corp_code': '00148939',
#    'corp_name': '조광피혁',
#    'stock_code': '004700',
#    'corp_cls': 'Y',
#    'report_nm': '[기재정정]반기보고서 (2022.06)',
#    'rcept_no': '20220818000332',
#    'flr_nm': '조광피혁',
#    'rcept_dt': '20220818',
#    'rm': ''},
#   {'corp_code': '00148939',
#    'corp_name': '조광피혁',
#    'stock_code': '004700',
#    'corp_cls': 'Y',
#    'report_nm': '[기재정정]분기보고서 (2022.03)',
#    'rcept_no': '20220818000331',
#    'flr_nm': '조광피혁',
#    'rcept_dt': '20220818',
#    'rm': ''},
#   {'corp_code': '00148939',
#    'corp_name': '조광피혁',
#    'stock_code': '004700',
#    'corp_cls': 'Y',
# ...

# %%
disclosures_frame = pd.DataFrame()
for i in tqdm(range(1, 107)):
    for pblntf_ty_data in pblntf_ty:
        disclosure_search = f'https://opendart.fss.or.kr/api/list.json?crtfc_key={api_key}&bgn_de={bgn_de}&end_de={end_de}&pblnt_ty={pblntf_ty_data}&corp_cls=Y&page_no={i}&page_count=10'
        response = requests.get(disclosure_search)
        eval_response = eval(response.text).get('list')
        response_pd = pd.DataFrame(eval_response)
        response_pd['']
print(disclosures)

# %% [markdown]
# ### 재무재표
#
# ```python
# https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json?crtfc_key=xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx&corp_code=00126380&bsns_year=2018&reprt_code=11011&fs_div=OFS
# ```

# %%
financial_statement_url = f'https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json?crtfc_key={api_key}&corp_code=00126380&bsns_year=2021&reprt_code=11011&fs_div=CFS'
response = requests.get(financial_statement_url)
eval_text2 = eval(response.text)
eval_text2_list = eval_text2.get('list')

# %%
a = eval_text2_list[0]
a
# Out:
# {'rcept_no': '20220308000798',
#  'reprt_code': '11011',
#  'bsns_year': '2021',
#  'corp_code': '00126380',
#  'sj_div': 'BS',
#  'sj_nm': '재무상태표',
#  'account_id': 'ifrs-full_CurrentAssets',
#  'account_nm': '유동자산',
#  'account_detail': '-',
#  'thstrm_nm': '제 53 기',
#  'thstrm_amount': '218163185000000',
#  'frmtrm_amount': '198215579000000',
#  'bfefrmtrm_amount': '181385260000000',
#  'ord': '1',
#  'currency': 'KRW'}

# %%
pd.DataFrame(eval(response.text).get('list')).iloc[:,:-7]
# Out:
#            rcept_no reprt_code bsns_year corp_code sj_div  sj_nm  \
# 0    20220308000798      11011      2021  00126380     BS  재무상태표
# 1    20220308000798      11011      2021  00126380     BS  재무상태표
# 2    20220308000798      11011      2021  00126380     BS  재무상태표
# 3    20220308000798      11011      2021  00126380     BS  재무상태표
# 4    20220308000798      11011      2021  00126380     BS  재무상태표
# ..              ...        ...       ...       ...    ...    ...
# 181  20220308000798      11011      2021  00126380    SCE  자본변동표
# 182  20220308000798      11011      2021  00126380    SCE  자본변동표
# 183  20220308000798      11011      2021  00126380    SCE  자본변동표
# 184  20220308000798      11011      2021  00126380    SCE  자본변동표
# 185  20220308000798      11011      2021  00126380    SCE  자본변동표
#
#                                             account_id       account_nm  \
# 0                              ifrs-full_CurrentAssets             유동자산
# ...

# %% [markdown]
# # Data Collection for Next Curriculum(HOMEWORK)

# %% [markdown]
# news (2021년 네이버 언론사 모바일 랭킹뉴스 및 점유율, 기자협회보)
# -2022.07.01 ~ 2022.08.31의 데이터
#
# -중앙일보, 한국경제, 조선일보, 매일경제, 머니투데이 등
#
# YOUTUBE
# -너덜트, 슈카월드 ,호갱구조대, 장삐쭈 (채널정보)
# 너덜트 : 오늘 수정이네 집에서 자고 가려고, 꿈이요? 퇴산데요
# 슈카월드 : 화려했던 비전펀드 창사 이래 최대 적자, 카페인이 필요한 사람들
# 호갱구조대: 님들이 뭔데요...? 선을 넘기 시작한 요즘의 예능들
# 1분만: 중2대 하면 안되는 것들, 내가 100만이 될 상인가?
# 장빼쭈 : [신병] 집합, [신병] 선택(영상정보)
#
# -영상별 댓글 수집(댓글정보)
#
# dart
#
# -국내  시가총액순 20위까지 테이블
# -기업 개황, 재무제표를 담은 테이블
#
# csv에 저장하는 방법
# pd.DataFrame().to_csv('./results.csv', index=False)
