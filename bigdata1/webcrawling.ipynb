# %% [markdown]
# # 네이버 뉴스 크롤링하기

# %% [markdown]
# ## step1. 특정표본 이용하여 추출해보기

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm

# %%
# list3=[]
# for page in range(1, 7):
#     url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=008&date=20220701&page={page}'
#     response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
#     soup=BeautifulSoup(response.text, 'html.parser')
#     naver_news_image_data =soup.select('ul>li>dl>dt>a')
#     list3.append(naver_news_image_data[0]['href'])
# print(len(list3))

# %%
# list3=[]
# for page in range(1, 7):
#     url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=008&date=20220701&page={page}'
#     response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
#     soup=BeautifulSoup(response.text, 'html.parser')
#     naver_news_image_data =soup.select('ul>li>dl>dt>a')
#     list3.append(naver_news_image_data[0]['href'])
# print(len(list3))

# %%
# list3=[]
# for page in range(1, 7):
#     url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=008&date=20220701&page={page}'
#     response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
#     soup=BeautifulSoup(response.text, 'html.parser')
#     naver_news_image_data =soup.select('ul>li>dl>dt>a')
#     list3.append(naver_news_image_data[0]['href'])
# print(len(list3))

# %%
# list = []
# naver_news_url_data = soup.select('ul>li>dl>dt>a')
# for i in naver_news_url_data:
#     if i['href'] in list:
#         continue
#     else:
#         list.append(i['href'])
# len(list)

# %%
# url = 'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=008&date=20220827&page=1000'
# response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
# soup = BeautifulSoup(response.text, 'html.parser')
# last_page = soup.select('div.paging>strong')[0].text
# last_page

# %%
# url = 'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=008&date=20220827'
# response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
# soup = BeautifulSoup(response.text, 'html.parser')
# naver_news_contents_data = soup.select('ul>li>dl>dd>span.lede')
# naver_news_contents_data[0].text

# %%
# list = []
# naver_news_url_data = soup.select('ul>li>dl>dt>a')
# for i in naver_news_url_data:
#     if i['href'] in list:
#         continue
#     else:
#         list.append(i['href'])
# len(list)

# %%
# list4 =[]
# naver_news_id_data = soup.select('ul>li>dl>dd>span.writing')
# for i in naver_news_id_data:
#     print(i.text)

# %%
# from tqdm import tqdm
# tqdm(range(20220701, 20220832))

# %% [markdown]
# ## 함수 만들어서 네이버 뉴스 추출하기

# %% [markdown]
# 제목 추출하기

# %%
list1=[]
oid = ''
def naver_news_title(list1, oid):
    for date in tqdm(range(20220701, 20220832)):
        url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&listType=summary&oid={oid}&date={date}&page=1000'
        response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
        soup = BeautifulSoup(response.text, 'html.parser')
        last_page_data = soup.select('div.paging>strong')[0]
        last_page = int(last_page_data.text)
        for page in range(1, last_page + 1):
            url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&listType=summary&oid={oid}&date={date}&page={page}'
            soup = BeautifulSoup(response.text, 'html.parser')
            response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
            naver_news_data = soup.select('ul.type06_headline>li>dl>dt>a') + soup.select('ul.type06>li>dl>dt>a')
            for i in naver_news_data:
                if i.select('img') == []:
                    list1.append(i.text.strip())
                else:
                    continue
    return list1

# %% [markdown]
# 내용 추출하기

# %%
list2= []
oid= ''
def naver_news_content(list2, oid):
    for date in tqdm(range(20220701, 20220832)):
        url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&listType=summary&oid={oid}&date={date}&page=1000'
        response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
        soup = BeautifulSoup(response.text, 'html.parser')
        last_page_data = soup.select('div.paging>strong')[0]
        last_page = int(last_page_data.text)
        for page in range(1, last_page+1):
            url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&listType=summary&oid={oid}&date={date}&page={page}'
            response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
            soup = BeautifulSoup(response.text, 'html.parser')
            naver_news_contents_data = soup.select('ul.type06_headline>li>dl>dd>span.lede') + soup.select('ul.type06>li>dl>dd>span.lede')
            for s in naver_news_contents_data:
                list2.append(s.text.strip())
    return list2

# %% [markdown]
# 뉴스 출처 홈페이지 추출하기

# %%
list3 =[]
oid=''
def naver_news_url(list3, oid):
    for date in tqdm(range(20220701, 20220832)):
        url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&listType=summary&oid={oid}&date={date}&page=1000'
        response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
        soup = BeautifulSoup(response.text, 'html.parser')
        last_page_data = soup.select('div.paging>strong')[0]
        last_page = int(last_page_data.text)
        for page in range(1, last_page+1):
            url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&listType=summary&oid={oid}&date={date}&page={page}'
            response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
            soup=BeautifulSoup(response.text, 'html.parser')
            naver_news_image_data =soup.select('ul.type06_headline>li>dl>dt>a') + soup.select('ul.type06>li>dl>dt>a')
            for i in naver_news_image_data:
                if i.select('img')==[]:
                    list3.append(i['href'])
                else:
                    continue

    return list3

# %% [markdown]
# 뉴스 회사 추출하기

# %%
list4 = []
oid=''
def naver_news_id(list4, oid):
    for date in tqdm(range(20220701, 20220832)):
        url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&listType=summary&oid={oid}&date={date}&page=1000'
        response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
        soup = BeautifulSoup(response.text, 'html.parser')
        last_page_data = soup.select('div.paging>strong')[0]
        last_page = int(last_page_data.text)
        for page in range(1, last_page+1):
            url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&listType=summary&oid={oid}&date={date}&page={page}'
            response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
            soup=BeautifulSoup(response.text, 'html.parser')
            naver_news_id_data =soup.select('ul.type06_headline>li>dl>dd>span.writing') + soup.select('ul.type06>li>dl>dd>span.writing')
            for id in naver_news_id_data:
                list4.append(id.text)
    return list4

# %%
# url = 'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=008&date=20220827&page=1000'
# response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
# soup=BeautifulSoup(response.text, 'html.parser')
# naver_news_id_data =soup.select('div>ul>li>dl>dd>span.writing')
# print(naver_news_id_data[0].text)
# last_page = int(soup.select('div.paging>strong')[0].text)
# print(last_page)

# %%
# oid = ['008', '009', '015', '023', '025']

# %% [markdown]
# 뉴스 제목 데이터수 확인하기

# %%
print(len(naver_news_title([],'008')))
# Out:
# 100%|██████████| 131/131 [07:54<00:00,  3.62s/it]
# 25630

# %% [markdown]
# 뉴스 내용 데이터 수 확인하기

# %%
print(len(naver_news_content([],'008')))
# Out:
# 100%|██████████| 131/131 [07:37<00:00,  3.49s/it]
# 25630

# %% [markdown]
# 뉴스 출처 데이터 수 확인하기

# %%
print(len(naver_news_url([],'008')))
# Out:
# 100%|██████████| 131/131 [08:03<00:00,  3.69s/it]
# 25630

# %% [markdown]
# 뉴스 회사 데이터 수 확인하기

# %%
print(len(naver_news_id([],'008')))
# Out:
# 100%|██████████| 131/131 [08:37<00:00,  3.95s/it]
# 25630

# %% [markdown]
# ## 신문 회사에 대한 데이터 프레임 생성하기

# %%
money_today_news_data = pd.DataFrame({
    "id": naver_news_id([],'008'),
    "title": naver_news_title([],'008'),
    "content": naver_news_content([],'008'),
    "url": naver_news_url([],'008')
})
# Out:
# 100%|██████████| 131/131 [07:21<00:00,  3.37s/it]
# 100%|██████████| 131/131 [07:38<00:00,  3.50s/it]
# 100%|██████████| 131/131 [08:03<00:00,  3.69s/it]
# 100%|██████████| 131/131 [07:39<00:00,  3.51s/it]

# %%
mail_economy_news_data = pd.DataFrame({
    "id": naver_news_id([],'009'),
    "title": naver_news_title([],'009'),
    "content": naver_news_content([],'009'),
    "url": naver_news_url([],'009')
})
# Out:
# 100%|██████████| 131/131 [08:20<00:00,  3.82s/it]
# 100%|██████████| 131/131 [08:56<00:00,  4.10s/it]
# 100%|██████████| 131/131 [09:20<00:00,  4.28s/it]
# 100%|██████████| 131/131 [09:29<00:00,  4.35s/it]

# %%
middle_eilbo_news_data = pd.DataFrame({
    "id": naver_news_id([],'025'),
    "title": naver_news_title([],'025'),
    "content": naver_news_content([],'025'),
    "url": naver_news_url([],'025')
})
# Out:
# 100%|██████████| 131/131 [05:38<00:00,  2.58s/it]
# 100%|██████████| 131/131 [06:52<00:00,  3.15s/it]
# 100%|██████████| 131/131 [06:22<00:00,  2.92s/it]
# 100%|██████████| 131/131 [06:36<00:00,  3.03s/it]

# %%
chosun_eilbo_news_data = pd.DataFrame({
    "id": naver_news_id([],'023'),
    "title": naver_news_title([],'023'),
    "content": naver_news_content([],'023'),
    "url": naver_news_url([],'023')
})
# Out:
# 100%|██████████| 131/131 [06:24<00:00,  2.94s/it]
# 100%|██████████| 131/131 [05:47<00:00,  2.65s/it]
# 100%|██████████| 131/131 [04:58<00:00,  2.28s/it]
# 100%|██████████| 131/131 [05:52<00:00,  2.69s/it]

# %%
korean_economy_news_data = pd.DataFrame({
    "id": naver_news_id([],'015'),
    "title": naver_news_title([],'015'),
    "content": naver_news_content([],'015'),
    "url": naver_news_url([],'015')
})
# Out:
# 100%|██████████| 131/131 [10:20<00:00,  4.74s/it]
# 100%|██████████| 131/131 [11:12<00:00,  5.13s/it]
# 100%|██████████| 131/131 [09:25<00:00,  4.31s/it]
# 100%|██████████| 131/131 [10:17<00:00,  4.71s/it]

# %% [markdown]
# ## CSV로 저장하기

# %%
money_today_news_data.to_csv("money_today.csv", index=False, encoding="utf-8-sig")

# %%
mail_economy_news_data.to_csv('mail_economy.csv', index=False, encoding="utf-8-sig")

# %%
middle_eilbo_news_data.to_csv('middle_eilbo.csv', index=False, encoding="utf-8-sig")

# %%
chosun_eilbo_news_data.to_csv('chosun_eilbo.csv', index=False, encoding="utf-8-sig")

# %%
korean_economy_news_data.to_csv('korean_economy.csv', index=False, encoding="utf-8-sig")

# %% [markdown]
# # Youtube API 이용하여 크롤링하기

# %% [markdown]
# 특정으로 추출하기

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser

import pandas as pd


DEVELOPER_KEY='AIzaSyDitP67cnauWgzSvRqh0dbV9NAYMK6n5I4'
YOUTUBE_API_SERVICE_NAME='youtube'
YOUTUBE_API_VERSION='v3'

youtube = build(
  YOUTUBE_API_SERVICE_NAME,
  YOUTUBE_API_VERSION,
  developerKey=DEVELOPER_KEY
  )

# %%
# response = (
#     youtube
#     .commentThreads()
#     .list(
#       part='snippet,replies', 
#       videoId='627HBcT1jWY', 
#       maxResults=100
#       )
#     .execute()
#     )
# response

# %%
# while response = (
#     youtube
#     .commentThreads()
#     .list(
#       part='snippet,replies', 
#       videoId='eacvvczvPLo', 
#       maxResults=100
#       )
#     .execute()
#     )
# response

# %%
response=(
            youtube
            .commentThreads()
            .list(
            part='snippet,replies', 
            videoId='', 
            maxResults=100
            )
        .execute()
        )
list5=[]
videoiddata=''
def youtube_comments(list5, videoiddata):
    while response.get('pageToken'):
        if 'nextPageToken' in response:
            response2=(
                youtube
                .commentThreads()
                .list(
                part='snippet,replies', 
                videoId=videoiddata, 
                pageToken=response.get('nextPageToken'),
                maxResults=100
                )
            .execute()
            )
        else:
            break
    return [response2.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('textOriginal') for i in range(len(response.get('items')))]
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# c:\bigdata_git\bigdata_thunder\bigdata1\webcrawling.ipynb 셀 49 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/webcrawling.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> response=(
# ----> <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/webcrawling.ipynb#X36sZmlsZQ%3D%3D?line=1'>2</a>             youtube
#       <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/webcrawling.ipynb#X36sZmlsZQ%3D%3D?line=2'>3</a>             .commentThreads()
#       <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/webcrawling.ipynb#X36sZmlsZQ%3D%3D?line=3'>4</a>             .list(
#       <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/webcrawling.ipynb#X36sZmlsZQ%3D%3D?line=4'>5</a>             part='snippet,replies',
#       <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/webcrawling.ipynb#X36sZmlsZQ%3D%3D?line=5'>6</a>             videoId='',
#       <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/webcrawling.ipynb#X36sZmlsZQ%3D%3D?line=6'>7</a>             maxResults=100
#       <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/webcrawling.ipynb#X36sZmlsZQ%3D%3D?line=7'>8</a>             )
#       <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/webcrawling.ipynb#X36sZmlsZQ%3D%3D?line=8'>9</a>         .execute()
#      <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/webcrawling.ipynb#X36sZmlsZQ%3D%3D?line=9'>10</a>         )
#      <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/webcrawling.ipynb#X36sZmlsZQ%3D%3D?line=10'>11</a> list5=[]
#      <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/webcrawling.ipynb#X36sZmlsZQ%3D%3D?line=11'>12</a> videoiddata=''
#
# File c:\Python38\lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File c:\Python38\lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=&maxResults=100&key=AIzaSyDitP67cnauWgzSvRqh0dbV9NAYMK6n5I4&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">

# %%
response = (
    youtube
    .commentThreads()
    .list(
      part='snippet,replies', 
      videoId='627HBcT1jWY', 
      maxResults=100
      )
    .execute()
    )

# %% [markdown]
# # Dart

# %% [markdown]
# 특정 정보 추출하기

# %%
import pandas as pd
import requests
from tqdm import tqdm
from bs4 import BeautifulSoup
import xmltodict
import json
import time

# %%
api_key = '03880acf9b9a1701f822dbbe25c4340eaaddfe57'

# %%
dart_information_url = f'https://opendart.fss.or.kr/api/list.json?crtfc_key={api_key}&bgn_de=20200117&end_de=20200117&corp_cls=Y&page_no=1&page_count=10'

# %%
# dart_information_source = requests.get(dart_information_url)
# eval(dart_information_source.text)

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\bigdata_git\bigdata_thunder\bigdata1\webcrawling.ipynb 셀 44 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/webcrawling.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> with open("CORPCODE.xml",'r') as f:
#       <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/webcrawling.ipynb#X50sZmlsZQ%3D%3D?line=1'>2</a>     xmlString = f.read()
#       <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/webcrawling.ipynb#X50sZmlsZQ%3D%3D?line=3'>4</a> jsonString = json.dumps(xmltodict.parse(xmlString), indent=4)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'CORPCODE.xml'

# %%
# for name in tree.getroot().iter('list'):
#     print(list(name))

# %%
import requests
import io
import zipfile
import xmltodict
import pandas as pd

# %%
key = "03880acf9b9a1701f822dbbe25c4340eaaddfe57"
url = "https://opendart.fss.or.kr/api/corpCode.xml"

params = {
    "crtfc_key": key
}
resp = requests.get(url, params=params)

# %%
# f = io.BytesIO(resp.content)
# zfile = zipfile.ZipFile(f)
# zfile.namelist()
# xml = zfile.read("CORPCODE.xml").decode("utf-8")
# dict_data = xmltodict.parse(xml)
# code_lists = dict_data.get('result').get('list')
# list1 = []
# for code_list in code_lists:
#     list1.append(code_list.get('corp_code'))
# print(list1)

# %%
api_key = 'aad8902f062d010bc147854f95f914ff684f3092'

# %%
def industry_economy(corp_code):
    api_key = 'aad8902f062d010bc147854f95f914ff684f3092'
    url = f'https://opendart.fss.or.kr/api/company.json?crtfc_key={api_key}&corp_code={corp_code}'
    response = requests.get(url)
    return eval(response.text)
# Out:
# {'status': '000',
#  'message': '정상',
#  'corp_code': '00126380',
#  'corp_name': '삼성전자(주)',
#  'corp_name_eng': 'SAMSUNG ELECTRONICS CO,.LTD',
#  'stock_name': '삼성전자',
#  'stock_code': '005930',
#  'ceo_nm': '한종희, 경계현',
#  'corp_cls': 'Y',
#  'jurir_no': '1301110006246',
#  'bizr_no': '1248100998',
#  'adres': '경기도 수원시 영통구  삼성로 129 (매탄동)',
#  'hm_url': 'www.sec.co.kr',
#  'ir_url': '',
#  'phn_no': '031-200-1114',
#  'fax_no': '031-200-7538',
#  'induty_code': '264',
#  'est_dt': '19690113',
#  'acc_mt': '12'}

# %%
def dart_economy(corp_code):
    api_key = 'aad8902f062d010bc147854f95f914ff684f3092'
    search_url = f'https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json?crtfc_key={api_key}&corp_code={corp_code}&bsns_year=2021&reprt_code=11011&fs_div=OFS'
    search_response = requests.get(search_url)
    return eval(search_response.text).get('list')
# Out:
# {'status': '000',
#  'message': '정상',
#  'list': [{'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_CurrentAssets',
#    'account_nm': '유동자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '72659080000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '80039455000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '70155189000000',
#    'ord': '1',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_CashAndCashEquivalents',
#    'account_nm': '현금및현금성자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '2081917000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '2607957000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '2763768000000',
#    'ord': '2',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_ShortTermDepositsNotClassifiedAsCashEquivalents',
#    'account_nm': '단기금융상품',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '26501392000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '34113871000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '25510064000000',
#    'ord': '3',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_ShortTermTradeReceivable',
#    'account_nm': '매출채권',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '26255438000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '24933267000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '27881777000000',
#    'ord': '4',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_ShortTermOtherReceivables',
#    'account_nm': '미수금',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '2406795000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '1515079000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '2201402000000',
#    'ord': '5',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '선급금',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '908288000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '807262000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '1097598000000',
#    'ord': '6',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '선급비용',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '813651000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '2230628000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '2281179000000',
#    'ord': '7',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_Inventories',
#    'account_nm': '재고자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '12201712000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '12440951000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '7837144000000',
#    'ord': '8',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_OtherCurrentAssets',
#    'account_nm': '기타유동자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '1489887000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '1390440000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '582257000000',
#    'ord': '9',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_NoncurrentAssets',
#    'account_nm': '비유동자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '143521840000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '138981902000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '128086171000000',
#    'ord': '10',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '장기매도가능금융자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '973353000000',
#    'ord': '11',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '기타포괄손익-공정가치금융자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '1206080000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '1098565000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '',
#    'ord': '12',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '당기손익-공정가치금융자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '3181000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '7413000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '',
#    'ord': '13',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_InvestmentsInSubsidiariesJointVenturesAndAssociates',
#    'account_nm': '종속기업, 관계기업 및 공동기업 투자',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '56571252000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '55959745000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '55671759000000',
#    'ord': '14',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_PropertyPlantAndEquipment',
#    'account_nm': '유형자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '74090275000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '70602493000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '62816961000000',
#    'ord': '15',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_IntangibleAssetsOtherThanGoodwill',
#    'account_nm': '무형자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '8008653000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '2901476000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '2827035000000',
#    'ord': '16',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_DepositsForSeveranceInsurance',
#    'account_nm': '순확정급여자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '486855000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '562356000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '811210000000',
#    'ord': '17',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_DeferredTaxAssets',
#    'account_nm': '이연법인세자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '547176000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '654456000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '586161000000',
#    'ord': '18',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_OtherNonCurrentAssets',
#    'account_nm': '기타비유동자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '2608368000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '7195398000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '4399692000000',
#    'ord': '19',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_Assets',
#    'account_nm': '자산총계',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '216180920000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '219021357000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '198241360000000',
#    'ord': '20',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_CurrentLiabilities',
#    'account_nm': '유동부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '36237164000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '43145053000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '44495084000000',
#    'ord': '22',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '매입채무',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '7547273000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '7315631000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '6398629000000',
#    'ord': '23',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_ShorttermBorrowings',
#    'account_nm': '단기차입금',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '10228216000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '10353873000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '12229701000000',
#    'ord': '24',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '미지급금',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '9142890000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '8385752000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '9598654000000',
#    'ord': '25',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '선수금',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '355562000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '214615000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '214007000000',
#    'ord': '26',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '예수금',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '383450000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '572702000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '500740000000',
#    'ord': '27',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '미지급비용',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '5359291000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '6129837000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '6657674000000',
#    'ord': '28',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_CurrentTaxLiabilities',
#    'account_nm': '당기법인세부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '788846000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '7925887000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '6565781000000',
#    'ord': '29',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '유동성장기부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '153942000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '5440000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '5201000000',
#    'ord': '30',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_CurrentProvisions',
#    'account_nm': '충당부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '2042039000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '2135314000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '2273688000000',
#    'ord': '31',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_OtherCurrentLiabilities',
#    'account_nm': '기타유동부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '235655000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '106002000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '51009000000',
#    'ord': '32',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_NoncurrentLiabilities',
#    'account_nm': '비유동부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '2073509000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '2888179000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '2176501000000',
#    'ord': '33',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_BondsIssued',
#    'account_nm': '사채',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '39520000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '43516000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '46808000000',
#    'ord': '34',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_LongTermBorrowingsGross',
#    'account_nm': '장기차입금',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '174651000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '',
#    'ord': '35',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_LongTermOtherPayablesGross',
#    'account_nm': '장기미지급금',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '1574535000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '2472416000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '1750379000000',
#    'ord': '36',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_NoncurrentProvisions',
#    'account_nm': '장기충당부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '283508000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '372217000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '379201000000',
#    'ord': '37',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_OtherNonCurrentLiabilities',
#    'account_nm': '기타비유동부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '1295000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '30000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '113000000',
#    'ord': '38',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_Liabilities',
#    'account_nm': '부채총계',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '38310673000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '46033232000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '46671585000000',
#    'ord': '39',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_IssuedCapital',
#    'account_nm': '자본금',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '897514000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '897514000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '897514000000',
#    'ord': '41',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_IssuedCapitalOfPreferredStock',
#    'account_nm': '우선주자본금',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '119467000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '119467000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '119467000000',
#    'ord': '42',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_IssuedCapitalOfCommonStock',
#    'account_nm': '보통주자본금',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '778047000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '778047000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '778047000000',
#    'ord': '43',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_SharePremium',
#    'account_nm': '주식발행초과금',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '4403893000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '4403893000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '4403893000000',
#    'ord': '44',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_RetainedEarnings',
#    'account_nm': '이익잉여금(결손금)',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '172288326000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '166555532000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '150928724000000',
#    'ord': '45',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_ElementsOfOtherStockholdersEquity',
#    'account_nm': '기타자본항목',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '280514000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '1131186000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '-4660356000000',
#    'ord': '46',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '자본총계',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '177870247000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '172988125000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '151569775000000',
#    'ord': '47',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_EquityAndLiabilities',
#    'account_nm': '자본과부채총계',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '216180920000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '219021357000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '198241360000000',
#    'ord': '48',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs-full_Revenue',
#    'account_nm': '수익(매출액)',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '154772859000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '170381870000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '161915007000000',
#    'ord': '0',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs-full_CostOfSales',
#    'account_nm': '매출원가',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '113618444000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '101666506000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '101399657000000',
#    'ord': '1',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs-full_GrossProfit',
#    'account_nm': '매출총이익',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '41154415000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '68715364000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '60515350000000',
#    'ord': '2',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'dart_TotalSellingGeneralAdministrativeExpenses',
#    'account_nm': '판매비와관리비',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '27039348000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '25015913000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '25658259000000',
#    'ord': '3',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'dart_OperatingIncomeLoss',
#    'account_nm': '영업이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '14115067000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '43699451000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '34857091000000',
#    'ord': '4',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'dart_OtherGains',
#    'account_nm': '기타수익',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '5223302000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '972145000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '2767967000000',
#    'ord': '5',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'dart_OtherLosses',
#    'account_nm': '기타비용',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '678565000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '504562000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '1065014000000',
#    'ord': '6',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs-full_FinanceIncome',
#    'account_nm': '금융수익',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '4281534000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '3737494000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '4075602000000',
#    'ord': '7',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '금융비용',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '3908869000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '3505673000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '4102094000000',
#    'ord': '8',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs-full_ProfitLossBeforeTax',
#    'account_nm': '법인세비용차감전순이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '19032469000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '44398855000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '36533552000000',
#    'ord': '9',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs-full_IncomeTaxExpenseContinuingOperations',
#    'account_nm': '법인세비용',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '3679146000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '11583728000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '7732715000000',
#    'ord': '10',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs-full_ProfitLossFromContinuingOperations',
#    'account_nm': '계속영업이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '15353323000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '32815127000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '28800837000000',
#    'ord': '11',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs-full_ProfitLoss',
#    'account_nm': '당기순이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '15353323000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '32815127000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '28800837000000',
#    'ord': '12',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs-full_BasicEarningsLossPerShare',
#    'account_nm': '기본주당이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '2260',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '4830',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '4178',
#    'ord': '14',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'IS',
#    'sj_nm': '손익계산서',
#    'account_id': 'ifrs-full_DilutedEarningsLossPerShare',
#    'account_nm': '희석주당이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '2260',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '4830',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '4178',
#    'ord': '15',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_ProfitLoss',
#    'account_nm': '당기순이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '15353323000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '32815127000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '28800837000000',
#    'ord': '0',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_OtherComprehensiveIncome',
#    'account_nm': '기타포괄손익',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '-851958000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-378321000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '319724000000',
#    'ord': '1',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_OtherComprehensiveIncomeThatWillNotBeReclassifiedToProfitOrLossNetOfTax',
#    'account_nm': '후속적으로 당기손익으로 재분류되지 않는 포괄손익',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '-851958000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-378321000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '349950000000',
#    'ord': '2',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '기타포괄손익-공정가치금융자산평가손익',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '73199000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-88340000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '',
#    'ord': '3',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '순확정급여자산 재측정요소',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '-925157000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-289981000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '349950000000',
#    'ord': '4',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_OtherComprehensiveIncomeThatWillBeReclassifiedToProfitOrLossNetOfTax',
#    'account_nm': '후속적으로 당기손익으로 재분류되는 포괄손익',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '-30226000000',
#    'ord': '5',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '매도가능금융자산평가손익',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '-30226000000',
#    'ord': '6',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_ComprehensiveIncome',
#    'account_nm': '총포괄손익',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '14501365000000',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '32436806000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '29120561000000',
#    'ord': '7',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_CashFlowsFromUsedInOperatingActivities',
#    'account_nm': '영업활동 현금흐름',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '22796257000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '44341217000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '38906190000000',
#    'ord': '0',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_ProfitLossForStatementOfCashFlows',
#    'account_nm': '영업에서 창출된 현금흐름',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '28344706000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '53596311000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '41350471000000',
#    'ord': '1',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '당기순이익',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '15353323000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '32815127000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '28800837000000',
#    'ord': '2',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '조정',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '16911222000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '27095149000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '18012976000000',
#    'ord': '3',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '영업활동으로 인한 자산부채의 변동',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '-3919839000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-6313965000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '-5463342000000',
#    'ord': '4',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_InterestReceivedClassifiedAsOperatingActivities',
#    'account_nm': '이자의 수취',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '673363000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '459074000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '491501000000',
#    'ord': '5',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_InterestPaidClassifiedAsOperatingActivities',
#    'account_nm': '이자의 지급',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '306633000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '343270000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '265364000000',
#    'ord': '6',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_DividendsReceivedClassifiedAsOperatingActivities',
#    'account_nm': '배당금 수입',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '4625181000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '779567000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '1118779000000',
#    'ord': '7',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_IncomeTaxesPaidRefundClassifiedAsOperatingActivities',
#    'account_nm': '법인세 납부액',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '10540360000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '10150465000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '3789197000000',
#    'ord': '8',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_CashFlowsFromUsedInInvestingActivities',
#    'account_nm': '투자활동 현금흐름',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '-13537171000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-31678548000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '-28118806000000',
#    'ord': '9',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '단기금융상품의 순감소(증가)',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '6212479000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-7203807000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '2960592000000',
#    'ord': '10',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_ProceedsFromSalesOfLongTermFinancialInstruments',
#    'account_nm': '장기금융상품의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '1400000000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '1700000000000',
#    'ord': '11',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_PurchaseOfLongTermFinancialInstruments',
#    'account_nm': '장기금융상품의 취득',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '1860000000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '500000000000',
#    'ord': '12',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '장기매도가능금융자산의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '98265000000',
#    'ord': '13',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '장기매도가능금융자산의 취득',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '-163765000000',
#    'ord': '14',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '기타포괄손익-공정가치금융자산의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '1239000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '7345000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '',
#    'ord': '15',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '기타포괄손익-공정가치금융자산의 취득',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '-6701000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-204055000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '',
#    'ord': '16',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '당기손익-공정가치금융자산의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '7334000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '7421000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '',
#    'ord': '17',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '당기손익-공정가치금융자산의 취득',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-1776000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '',
#    'ord': '18',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '종속기업, 관계기업 및 공동기업 투자의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '58677000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '25846000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '1438362000000',
#    'ord': '19',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '종속기업, 관계기업 및 공동기업 투자의 취득',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '-925139000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-520660000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '-7492843000000',
#    'ord': '20',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_ProceedsFromSalesOfPropertyPlantAndEquipmentClassifiedAsInvestingActivities',
#    'account_nm': '유형자산의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '600901000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '340558000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '244033000000',
#    'ord': '21',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_PurchaseOfPropertyPlantAndEquipmentClassifiedAsInvestingActivities',
#    'account_nm': '유형자산의 취득',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '17240242000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '21387378000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '25641229000000',
#    'ord': '22',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_ProceedsFromSalesOfIntangibleAssetsClassifiedAsInvestingActivities',
#    'account_nm': '무형자산의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '1965000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '706000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '456000000',
#    'ord': '23',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_PurchaseOfIntangibleAssetsClassifiedAsInvestingActivities',
#    'account_nm': '무형자산의 취득',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '2855959000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '880032000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '843096000000',
#    'ord': '24',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '사업결합으로 인한 현금유출액',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '-785000000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '',
#    'ord': '25',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '기타투자활동으로 인한 현금유출입액',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '-6725000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-2716000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '80419000000',
#    'ord': '26',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_CashFlowsFromUsedInFinancingActivities',
#    'account_nm': '재무활동 현금흐름',
#    'account_detail': '-',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '-9787719000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-12818480000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '-11801987000000',
#    'ord': '27',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
# ...
#    'account_id': 'dart_EquityAtBeginningOfPeriod',
#    'account_nm': '기초자본',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '172988125000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '151569775000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '137546762000000',
#    'ord': '1',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_EquityAtBeginningOfPeriod',
#    'account_nm': '기초자본',
#    'account_detail': '자본 [member]|기타자본항목',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '1131186000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-4660356000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '-8502219000000',
#    'ord': '1',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_EquityAtBeginningOfPeriod',
#    'account_nm': '기초자본',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '166555532000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '150928724000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '140747574000000',
#    'ord': '1',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_EquityAtBeginningOfPeriod',
#    'account_nm': '기초자본',
#    'account_detail': '자본 [member]|자본금 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '897514000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '897514000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '897514000000',
#    'ord': '1',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_EquityAtBeginningOfPeriod',
#    'account_nm': '기초자본',
#    'account_detail': '자본 [member]|주식발행초과금',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '4403893000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '4403893000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '4403893000000',
#    'ord': '1',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_IncreaseDecreaseThroughChangesInAccountingPolicies',
#    'account_nm': '회계정책변경누적효과',
#    'account_detail': '자본 [member]|기타자본항목',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-61021000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '',
#    'ord': '2',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_IncreaseDecreaseThroughChangesInAccountingPolicies',
#    'account_nm': '회계정책변경누적효과',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '61021000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '',
#    'ord': '2',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '수정후 기초자본',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '172988125000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '151569775000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '137546762000000',
#    'ord': '3',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '수정후 기초자본',
#    'account_detail': '자본 [member]|기타자본항목',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '1131186000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-4721377000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '-8502219000000',
#    'ord': '3',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '수정후 기초자본',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '166555532000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '150989745000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '140747574000000',
#    'ord': '3',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '수정후 기초자본',
#    'account_detail': '자본 [member]|자본금 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '897514000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '897514000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '897514000000',
#    'ord': '3',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '수정후 기초자본',
#    'account_detail': '자본 [member]|주식발행초과금',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '4403893000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '4403893000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '4403893000000',
#    'ord': '3',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_ProfitLoss',
#    'account_nm': '당기순이익(손실)',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '15353323000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '32815127000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '28800837000000',
#    'ord': '4',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_ProfitLoss',
#    'account_nm': '당기순이익(손실)',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '15353323000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '32815127000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '28800837000000',
#    'ord': '4',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '매도가능금융자산평가손익',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '-30226000000',
#    'ord': '5',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '매도가능금융자산평가손익',
#    'account_detail': '자본 [member]|기타자본항목',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '-30226000000',
#    'ord': '5',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_ChangesInReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncome',
#    'account_nm': '기타포괄손익-공정가치금융자산평가손익',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '73199000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-88340000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '',
#    'ord': '6',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_ChangesInReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncome',
#    'account_nm': '기타포괄손익-공정가치금융자산평가손익',
#    'account_detail': '자본 [member]|기타자본항목',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '74485000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-85643000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '',
#    'ord': '6',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_ChangesInReserveOfGainsAndLossesOnFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncome',
#    'account_nm': '기타포괄손익-공정가치금융자산평가손익',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '-1286000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-2697000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '',
#    'ord': '6',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '순확정급여자산 재측정요소',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '-925157000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-289981000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '349950000000',
#    'ord': '7',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '순확정급여자산 재측정요소',
#    'account_detail': '자본 [member]|기타자본항목',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '-925157000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-289981000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '349950000000',
#    'ord': '7',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_DividendsPaid',
#    'account_nm': '배당',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '9619243000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '10143345000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '6747124000000',
#    'ord': '8',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_DividendsPaid',
#    'account_nm': '배당',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '9619243000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '10143345000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '6747124000000',
#    'ord': '8',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_TreasuryShareTransactions',
#    'account_nm': '자기주식의 취득',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-875111000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '-8350424000000',
#    'ord': '9',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_TreasuryShareTransactions',
#    'account_nm': '자기주식의 취득',
#    'account_detail': '자본 [member]|기타자본항목',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-875111000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '-8350424000000',
#    'ord': '9',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '자기주식의 소각',
#    'account_detail': '자본 [member]|기타자본항목',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '7103298000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '11872563000000',
#    'ord': '10',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '자기주식의 소각',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '-7103298000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '-11872563000000',
#    'ord': '10',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '177870247000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '172988125000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '151569775000000',
#    'ord': '11',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|기타자본항목',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '280514000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '1131186000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '-4660356000000',
#    'ord': '11',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '172288326000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '166555532000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '150928724000000',
#    'ord': '11',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|자본금 [member]',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '897514000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '897514000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '897514000000',
#    'ord': '11',
#    'currency': 'KRW'},
#   {'rcept_no': '20200330003851',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00126380',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|주식발행초과금',
#    'thstrm_nm': '제 51 기',
#    'thstrm_amount': '4403893000000',
#    'frmtrm_nm': '제 50 기',
#    'frmtrm_amount': '4403893000000',
#    'bfefrmtrm_nm': '제 49 기',
#    'bfefrmtrm_amount': '4403893000000',
#    'ord': '11',
#    'currency': 'KRW'}]}

# %% [markdown]
# ## 기업 현황 함수 만들기

# %%
def industry_economics(corp_code):
    api_key = 'aad8902f062d010bc147854f95f914ff684f3092'
    url = f'https://opendart.fss.or.kr/api/company.json?crtfc_key={api_key}&corp_code={corp_code}'
    response = requests.get(url)
    return eval(response.text)

# %% [markdown]
# ## 재무 현황 함수 만들기

# %%
def search_item(corp_code, bsns_year):
    api_key = 'aad8902f062d010bc147854f95f914ff684f3092'
    search_url = f'https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json?crtfc_key={api_key}&corp_code={corp_code}&bsns_year={bsns_year}&reprt_code=11011&fs_div=CFS'
    search_response = requests.get(search_url)
    return eval(response.text)
