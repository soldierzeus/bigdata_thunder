# %% [markdown]
# # 네이버 뉴스 크롤링하기

# %% [markdown]
# ## step1. 특정표본 이용하여 추출해보기

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm

# %%
# list3=[]
# for page in range(1, 7):
#     url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=008&date=20220701&page={page}'
#     response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
#     soup=BeautifulSoup(response.text, 'html.parser')
#     naver_news_image_data =soup.select('ul>li>dl>dt>a')
#     list3.append(naver_news_image_data[0]['href'])
# print(len(list3))

# %%
# list3=[]
# for page in range(1, 7):
#     url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=008&date=20220701&page={page}'
#     response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
#     soup=BeautifulSoup(response.text, 'html.parser')
#     naver_news_image_data =soup.select('ul>li>dl>dt>a')
#     list3.append(naver_news_image_data[0]['href'])
# print(len(list3))

# %%
# list3=[]
# for page in range(1, 7):
#     url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=008&date=20220701&page={page}'
#     response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
#     soup=BeautifulSoup(response.text, 'html.parser')
#     naver_news_image_data =soup.select('ul>li>dl>dt>a')
#     list3.append(naver_news_image_data[0]['href'])
# print(len(list3))

# %%
# list = []
# naver_news_url_data = soup.select('ul>li>dl>dt>a')
# for i in naver_news_url_data:
#     if i['href'] in list:
#         continue
#     else:
#         list.append(i['href'])
# len(list)

# %%
# url = 'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=008&date=20220827&page=1000'
# response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
# soup = BeautifulSoup(response.text, 'html.parser')
# last_page = soup.select('div.paging>strong')[0].text
# last_page

# %%
# url = 'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=008&date=20220827'
# response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
# soup = BeautifulSoup(response.text, 'html.parser')
# naver_news_contents_data = soup.select('ul>li>dl>dd>span.lede')
# naver_news_contents_data[0].text

# %%
# list = []
# naver_news_url_data = soup.select('ul>li>dl>dt>a')
# for i in naver_news_url_data:
#     if i['href'] in list:
#         continue
#     else:
#         list.append(i['href'])
# len(list)

# %%
# list4 =[]
# naver_news_id_data = soup.select('ul>li>dl>dd>span.writing')
# for i in naver_news_id_data:
#     print(i.text)

# %%
# from tqdm import tqdm
# tqdm(range(20220701, 20220832))

# %% [markdown]
# ## 함수 만들어서 네이버 뉴스 추출하기

# %% [markdown]
# 제목 추출하기

# %%
list1=[]
oid = ''
def naver_news_title(list1, oid):
    for date in tqdm(range(20220701, 20220832)):
        url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&listType=summary&oid={oid}&date={date}&page=1000'
        response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
        soup = BeautifulSoup(response.text, 'html.parser')
        last_page_data = soup.select('div.paging>strong')[0]
        last_page = int(last_page_data.text)
        for page in range(1, last_page + 1):
            url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&listType=summary&oid={oid}&date={date}&page={page}'
            soup = BeautifulSoup(response.text, 'html.parser')
            response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
            naver_news_data = soup.select('ul.type06_headline>li>dl>dt>a') + soup.select('ul.type06>li>dl>dt>a')
            for i in naver_news_data:
                if i.select('img') == []:
                    list1.append(i.text.strip())
                else:
                    continue
    return list1

# %% [markdown]
# 내용 추출하기

# %%
list2= []
oid= ''
def naver_news_content(list2, oid):
    for date in tqdm(range(20220701, 20220832)):
        url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&listType=summary&oid={oid}&date={date}&page=1000'
        response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
        soup = BeautifulSoup(response.text, 'html.parser')
        last_page_data = soup.select('div.paging>strong')[0]
        last_page = int(last_page_data.text)
        for page in range(1, last_page+1):
            url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&listType=summary&oid={oid}&date={date}&page={page}'
            response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
            soup = BeautifulSoup(response.text, 'html.parser')
            naver_news_contents_data = soup.select('ul.type06_headline>li>dl>dd>span.lede') + soup.select('ul.type06>li>dl>dd>span.lede')
            for s in naver_news_contents_data:
                list2.append(s.text.strip())
    return list2

# %% [markdown]
# 뉴스 출처 홈페이지 추출하기

# %%
list3 =[]
oid=''
def naver_news_url(list3, oid):
    for date in tqdm(range(20220701, 20220832)):
        url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&listType=summary&oid={oid}&date={date}&page=1000'
        response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
        soup = BeautifulSoup(response.text, 'html.parser')
        last_page_data = soup.select('div.paging>strong')[0]
        last_page = int(last_page_data.text)
        for page in range(1, last_page+1):
            url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&listType=summary&oid={oid}&date={date}&page={page}'
            response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
            soup=BeautifulSoup(response.text, 'html.parser')
            naver_news_image_data =soup.select('ul.type06_headline>li>dl>dt>a') + soup.select('ul.type06>li>dl>dt>a')
            for i in naver_news_image_data:
                if i.select('img')==[]:
                    list3.append(i['href'])
                else:
                    continue

    return list3

# %% [markdown]
# 뉴스 회사 추출하기

# %%
list4 = []
oid=''
def naver_news_id(list4, oid):
    for date in tqdm(range(20220701, 20220832)):
        url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&listType=summary&oid={oid}&date={date}&page=1000'
        response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
        soup = BeautifulSoup(response.text, 'html.parser')
        last_page_data = soup.select('div.paging>strong')[0]
        last_page = int(last_page_data.text)
        for page in range(1, last_page+1):
            url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&listType=summary&oid={oid}&date={date}&page={page}'
            response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
            soup=BeautifulSoup(response.text, 'html.parser')
            naver_news_id_data =soup.select('ul.type06_headline>li>dl>dd>span.writing') + soup.select('ul.type06>li>dl>dd>span.writing')
            for id in naver_news_id_data:
                list4.append(id.text)
    return list4

# %%
# url = 'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=008&date=20220827&page=1000'
# response = requests.get(url, headers={'User-Agent': 'Mozilla 5.0'})
# soup=BeautifulSoup(response.text, 'html.parser')
# naver_news_id_data =soup.select('div>ul>li>dl>dd>span.writing')
# print(naver_news_id_data[0].text)
# last_page = int(soup.select('div.paging>strong')[0].text)
# print(last_page)

# %%
# oid = ['008', '009', '015', '023', '025']

# %% [markdown]
# 뉴스 제목 데이터수 확인하기

# %%
print(len(naver_news_title([],'008')))
# Out:
# 100%|██████████| 131/131 [07:54<00:00,  3.62s/it]
# 25630

# %% [markdown]
# 뉴스 내용 데이터 수 확인하기

# %%
print(len(naver_news_content([],'008')))
# Out:
# 100%|██████████| 131/131 [07:37<00:00,  3.49s/it]
# 25630

# %% [markdown]
# 뉴스 출처 데이터 수 확인하기

# %%
print(len(naver_news_url([],'008')))
# Out:
# 100%|██████████| 131/131 [08:03<00:00,  3.69s/it]
# 25630

# %% [markdown]
# 뉴스 회사 데이터 수 확인하기

# %%
print(len(naver_news_id([],'008')))
# Out:
# 100%|██████████| 131/131 [08:37<00:00,  3.95s/it]
# 25630

# %% [markdown]
# ## 신문 회사에 대한 데이터 프레임 생성하기

# %%
money_today_news_data = pd.DataFrame({
    "id": naver_news_id([],'008'),
    "title": naver_news_title([],'008'),
    "content": naver_news_content([],'008'),
    "url": naver_news_url([],'008')
})
# Out:
# 100%|██████████| 131/131 [07:21<00:00,  3.37s/it]
# 100%|██████████| 131/131 [07:38<00:00,  3.50s/it]
# 100%|██████████| 131/131 [08:03<00:00,  3.69s/it]
# 100%|██████████| 131/131 [07:39<00:00,  3.51s/it]

# %%
mail_economy_news_data = pd.DataFrame({
    "id": naver_news_id([],'009'),
    "title": naver_news_title([],'009'),
    "content": naver_news_content([],'009'),
    "url": naver_news_url([],'009')
})
# Out:
# 100%|██████████| 131/131 [08:20<00:00,  3.82s/it]
# 100%|██████████| 131/131 [08:56<00:00,  4.10s/it]
# 100%|██████████| 131/131 [09:20<00:00,  4.28s/it]
# 100%|██████████| 131/131 [09:29<00:00,  4.35s/it]

# %%
middle_eilbo_news_data = pd.DataFrame({
    "id": naver_news_id([],'025'),
    "title": naver_news_title([],'025'),
    "content": naver_news_content([],'025'),
    "url": naver_news_url([],'025')
})
# Out:
# 100%|██████████| 131/131 [06:09<00:00,  2.82s/it]
# 100%|██████████| 131/131 [05:58<00:00,  2.73s/it]
# 100%|██████████| 131/131 [06:19<00:00,  2.90s/it]
# 100%|██████████| 131/131 [06:20<00:00,  2.90s/it]

# %%
chosun_eilbo_news_data = pd.DataFrame({
    "id": naver_news_id([],'023'),
    "title": naver_news_title([],'023'),
    "content": naver_news_content([],'023'),
    "url": naver_news_url([],'023')
})
# Out:
# 100%|██████████| 131/131 [06:24<00:00,  2.94s/it]
# 100%|██████████| 131/131 [05:47<00:00,  2.65s/it]
# 100%|██████████| 131/131 [04:58<00:00,  2.28s/it]
# 100%|██████████| 131/131 [05:52<00:00,  2.69s/it]

# %%
korean_economy_news_data = pd.DataFrame({
    "id": naver_news_id([],'015'),
    "title": naver_news_title([],'015'),
    "content": naver_news_content([],'015'),
    "url": naver_news_url([],'015')
})
# Out:
# 100%|██████████| 131/131 [10:20<00:00,  4.74s/it]
# 100%|██████████| 131/131 [11:12<00:00,  5.13s/it]
# 100%|██████████| 131/131 [09:25<00:00,  4.31s/it]
# 100%|██████████| 131/131 [10:17<00:00,  4.71s/it]

# %% [markdown]
# ## CSV로 저장하기

# %%
money_today_news_data.to_csv("money_today.csv", index=False, encoding="utf-8-sig")

# %%
mail_economy_news_data.to_csv('mail_economy.csv', index=False, encoding="utf-8-sig")

# %%
middle_eilbo_news_data.to_csv('middle_eilbo.csv', index=False, encoding="utf-8-sig")

# %%
chosun_eilbo_news_data.to_csv('chosun_eilbo.csv', index=False, encoding="utf-8-sig")

# %%
korean_economy_news_data.to_csv('korean_economy.csv', index=False, encoding="utf-8-sig")

# %% [markdown]
# # Youtube API 이용하여 크롤링하기

# %% [markdown]
# 특정으로 추출하기

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser
from bs4 import BeautifulSoup
import pandas as pd


DEVELOPER_KEY='AIzaSyDitP67cnauWgzSvRqh0dbV9NAYMK6n5I4'
YOUTUBE_API_SERVICE_NAME='youtube'
YOUTUBE_API_VERSION='v3'

youtube = build(
  YOUTUBE_API_SERVICE_NAME,
  YOUTUBE_API_VERSION,
  developerKey=DEVELOPER_KEY
  )

# %%
response = (
    youtube
    .commentThreads()
    .list(
      part='snippet,replies', 
      videoId='627HBcT1jWY', 
      maxResults=100
      )
    .execute()
    )
response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': '_dunfOQCtbxA761XhcfkE4wlYPI',
#  'nextPageToken': 'QURTSl9pMEdMbk9CQkp1dl9BTWU3eDZoeW5lWFNRWThJOW1nQk9tb19hcGlqeW9ES21XRm52QmlpcFdIVHgwSl9rSVMzaEFSaGQyX0E0bw==',
#  'pageInfo': {'totalResults': 100, 'resultsPerPage': 100},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'yiH_eut2zDE40vJ-ffQdRRiEcVw',
#    'id': 'Ugz6AJE7if7mDaKqMQB4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'e9how1NXjTZo3T6KQ-k128oGNuE',
#      'id': 'Ugz6AJE7if7mDaKqMQB4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '이게 그 &#39;소심한 복수&#39;랑 이어지네 ㅋㅋㅋㅋ',
#       'textOriginal': "이게 그 '소심한 복수'랑 이어지네 ㅋㅋㅋㅋ",
#       'authorDisplayName': 'SangHyun Park',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-ghnusbqDj0wdyyE5mPb43WS_zEuYDF8S8rz5dqw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCb6ZFAH9T7m5-vYfPYdemSA',
#       'authorChannelId': {'value': 'UCb6ZFAH9T7m5-vYfPYdemSA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-01T14:48:15Z',
#       'updatedAt': '2022-09-01T14:48:15Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Urnj1UtUmv0AOgfHdZHDYiE0vn0',
#    'id': 'UgybDPV5TZDV4ezDx854AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '0lofmLNJER7tJGczKHFcqX-xEd0',
#      'id': 'UgybDPV5TZDV4ezDx854AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '여러번 지나가다 뜰때마다 다시보는 중인데 오늘은 문득...그 타로랑 비슷해보임 ㅎㅎㅎ',
#       'textOriginal': '여러번 지나가다 뜰때마다 다시보는 중인데 오늘은 문득...그 타로랑 비슷해보임 ㅎㅎㅎ',
#       'authorDisplayName': '태양같은너에게로 가는 길',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu8j913cjRHFTHSmSwlB_22BGUq97Ko-oOVk5eRGTw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCNXmEVaBFAcrEx9mvDDG-Mw',
#       'authorChannelId': {'value': 'UCNXmEVaBFAcrEx9mvDDG-Mw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-08-24T12:31:15Z',
#       'updatedAt': '2022-08-24T12:31:15Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'nmRuj_Q0cMmpw5CJC9D5nzmXLzk',
#    'id': 'UgyLVnshFp3R0Q9DU414AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'naKiT1rbz60xOlvzQ2rfdZjU2KQ',
#      'id': 'UgyLVnshFp3R0Q9DU414AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '이게 ㄹㅇ 명작이다..',
#       'textOriginal': '이게 ㄹㅇ 명작이다..',
#       'authorDisplayName': "Let's YS",
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu832J4IRzQUWeAco34SHPaIClb96PrkwJ5IFg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCvN3lTt_ikbCV2xQeaemI7w',
#       'authorChannelId': {'value': 'UCvN3lTt_ikbCV2xQeaemI7w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-08-17T09:40:00Z',
#       'updatedAt': '2022-08-17T09:40:00Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ThcWF0licW6rCNnr3oT68ixNRmE',
#    'id': 'UgzcbYkfcQsNfX5ZGbZ4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ruojc4gyyfFmDfnYIWlPT2BEYP8',
#      'id': 'UgzcbYkfcQsNfX5ZGbZ4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': 'Honestly, ever since I started watching Kdramas, I&#39;m amazed at how great Korean actors are. I mean, these guys here do it just for kicks on YouTube and they&#39;re better than actual actors in my country 🤣😭',
#       'textOriginal': "Honestly, ever since I started watching Kdramas, I'm amazed at how great Korean actors are. I mean, these guys here do it just for kicks on YouTube and they're better than actual actors in my country 🤣😭",
#       'authorDisplayName': 'Theodora Pilates',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_I-gLQCqydByzPdRMuNN-1SEBKbYORyx9gyP-n5w=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCHXPaEaxps6Rvr-Y4j8v2PQ',
#       'authorChannelId': {'value': 'UCHXPaEaxps6Rvr-Y4j8v2PQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-08-17T09:06:49Z',
#       'updatedAt': '2022-08-17T09:06:49Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'TbE7qlPvHkO0pRzumRgT9WfP2gk',
#    'id': 'UgzSh1XX4IJIgxSDCIR4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'VjZR-Q0xJ7F2uM3cgGKw3HCo6vo',
#      'id': 'UgzSh1XX4IJIgxSDCIR4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ팀장 아무도 하기 싫어해서ㅌㅌㅋㅋㅌ',
#       'textOriginal': 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ팀장 아무도 하기 싫어해서ㅌㅌㅋㅋㅌ',
#       'authorDisplayName': '이혜',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu9Fp_Rmh97fgRDwDF7shIJBEcasViBwpnAu-0IBDQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCI2ZQCs_F_wkzpO_0xCy4sQ',
#       'authorChannelId': {'value': 'UCI2ZQCs_F_wkzpO_0xCy4sQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-08-10T06:47:02Z',
#       'updatedAt': '2022-08-10T06:47:02Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'VIpCTi51FHv7Kx-g0BhcanuGXzg',
#    'id': 'UgwR9udVulz6mvO9phB4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '-XMmP3LN7YizHMroZOA0qDbXagE',
#      'id': 'UgwR9udVulz6mvO9phB4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '<a href="https://www.youtube.com/watch?v=627HBcT1jWY&amp;t=02m58s">02:58</a> 이때 팔걸...',
#       'textOriginal': '02:58 이때 팔걸...',
#       'authorDisplayName': '이상범',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_ZQkz5SR6xMN6sxxIEcQW4btHyhfUCnBcCyg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCfVOMUnar_jj7TdYMhbAHvg',
#       'authorChannelId': {'value': 'UCfVOMUnar_jj7TdYMhbAHvg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-08-09T13:25:43Z',
#       'updatedAt': '2022-08-09T13:25:57Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ITRMcanxSBHE5BaiQt10csf-vH0',
#    'id': 'UgzwB6ZHL8jQ-Q4qIuN4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '0QIqMv7jVRweg9YzxaRgQorCzxg',
#      'id': 'UgzwB6ZHL8jQ-Q4qIuN4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '팀장님... 난가??',
#       'textOriginal': '팀장님... 난가??',
#       'authorDisplayName': '푸푸',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/0kW32CbzsTA-i0tdAtDlZkTkQBZE_o-AuUlVdZNG2p6MHxxm8QB07TBavg9QvOlorX_08nwaMPQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCRRdop5USVh4cUkWE6QnhPQ',
#       'authorChannelId': {'value': 'UCRRdop5USVh4cUkWE6QnhPQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-08-09T04:21:19Z',
#       'updatedAt': '2022-08-09T04:21:19Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'mXAv0LPvSYoZt69TsxvuE5m6vx0',
#    'id': 'UgxUCVTnfujVHsWaBZ54AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ftJKe3xzfridxeztVLcooyW7mKQ',
#      'id': 'UgxUCVTnfujVHsWaBZ54AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '철저히 꿈도 희망도 없는 영상.',
#       'textOriginal': '철저히 꿈도 희망도 없는 영상.',
#       'authorDisplayName': '한',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-6pJuALM5gHXCxYRA8C6nGFriXOVTHjQq8Of_NEAWGnYOAU8Sywuk6iefHngqtxBcPS151rj=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCmCn3m0B9HQMhnsxIa_XL3w',
#       'authorChannelId': {'value': 'UCmCn3m0B9HQMhnsxIa_XL3w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-08-09T03:49:11Z',
#       'updatedAt': '2022-08-09T03:49:11Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'WkxWc7OAKBqMxSoSO6R1u2k6e7I',
#    'id': 'UgzQIEjuq94dICkMRaB4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '4almiwfJERtazhszfpI__-TXT40',
#      'id': 'UgzQIEjuq94dICkMRaB4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '아 ㅆ 내얘긴가ㅋㅋㅋㅋㅋㅋㅋ',
#       'textOriginal': '아 ㅆ 내얘긴가ㅋㅋㅋㅋㅋㅋㅋ',
#       'authorDisplayName': '겨울손',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu9eN9Ztehb079mDm8gLJxzhmRlFYi1UEuAPp9HZMw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCqvFI8UdNrhqdBbxnAWD5Bw',
#       'authorChannelId': {'value': 'UCqvFI8UdNrhqdBbxnAWD5Bw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-08-06T09:36:34Z',
#       'updatedAt': '2022-08-06T09:36:34Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'DaeWZJuXL2cNKeBRtsAH_4RpipY',
#    'id': 'UgxLXszYbQ8_V5wjf954AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '2Kg3KBmI4q6-bEl3Z9C6du_4df4',
#      'id': 'UgxLXszYbQ8_V5wjf954AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '카페에 누가 올려주신 당근마켓 보고 순례중입니다. 물론 구독과 좋아요도 잊지 않았습니다. 와......작년 12월?에 10만 감사 영상 찍으셨던데 132만......ㄷㄷ 자주 올게요!',
#       'textOriginal': '카페에 누가 올려주신 당근마켓 보고 순례중입니다. 물론 구독과 좋아요도 잊지 않았습니다. 와......작년 12월?에 10만 감사 영상 찍으셨던데 132만......ㄷㄷ 자주 올게요!',
#       'authorDisplayName': 'JIN',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_oiry6fuUL1yXqwBZcy2JBf5zOoqGvhyCGlQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCojOnyzGMonaJR1DQ-kGhyw',
#       'authorChannelId': {'value': 'UCojOnyzGMonaJR1DQ-kGhyw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-08-04T12:29:12Z',
#       'updatedAt': '2022-08-04T12:29:12Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '4wC_8aNI-lhDKnn11go6j9jxSbU',
#    'id': 'UgzNvoS3SH1UcLTGWg94AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'RDNvt8UYksaI3f_HVz6yRKazNHI',
#      'id': 'UgzNvoS3SH1UcLTGWg94AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '정치인들 CEO들이 진심으로 하고 싶어하는말을 진실대로 말해주니까 100점',
#       'textOriginal': '정치인들 CEO들이 진심으로 하고 싶어하는말을 진실대로 말해주니까 100점',
#       'authorDisplayName': '마신임(운명의신)',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/3xBBKMVWe5SaSPOzVKutN_T9IYBcjAPCDEcEVa7Bfx5OW-zCP-WRnNgk81BDGAla4WJAC7zBgg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCpwPCYZ467H-WgEOSFRSmdQ',
#       'authorChannelId': {'value': 'UCpwPCYZ467H-WgEOSFRSmdQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-08-03T05:50:00Z',
#       'updatedAt': '2022-08-03T05:50:00Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'oojlCDE3ebijcwF9zPYwVCi7nU4',
#    'id': 'Ugyl_LQ7BkSPfOrb2I54AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'lgE-nQdpJVXvEiX4Usa0eI2cAC4',
#      'id': 'Ugyl_LQ7BkSPfOrb2I54AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '정말 표현력이 좋으신거 같습니다. 영상들나하나 정말 퀄리티가 높은 거 같아요 이런 소재들을 항상 재미있게 풀어주시는 너덜트 님께 감사드립니다. 좋은 영상 항상 감사합니다.',
#       'textOriginal': '정말 표현력이 좋으신거 같습니다. 영상들나하나 정말 퀄리티가 높은 거 같아요 이런 소재들을 항상 재미있게 풀어주시는 너덜트 님께 감사드립니다. 좋은 영상 항상 감사합니다.',
#       'authorDisplayName': 'TPALS FL',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_kP-zgO4aVZhI8T08SyGypkS_1w-Ez-qsQOw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCp3Tyl6c_WkIlBveRCftAzg',
#       'authorChannelId': {'value': 'UCp3Tyl6c_WkIlBveRCftAzg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 3,
#       'publishedAt': '2022-07-31T12:33:40Z',
#       'updatedAt': '2022-07-31T12:33:40Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'KFN1HjIrGQt-Uk5NwvAr0sczgwY',
#    'id': 'Ugz5cJ-Ecn2bdU72Pfh4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '7GAmJ2MxoK-a2QGRfRGpuIVX09s',
#      'id': 'Ugz5cJ-Ecn2bdU72Pfh4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '썸넬: 유희열?',
#       'textOriginal': '썸넬: 유희열?',
#       'authorDisplayName': '늅',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/K54DFBy5NgXd880iOmKrqq3v3msmMHzbmSXe2y-JhPdgCwJVe4U-E4Lv2uQ7nmTwetWRmI5g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCSXsIRbVrTc8Sct-dkvWEuw',
#       'authorChannelId': {'value': 'UCSXsIRbVrTc8Sct-dkvWEuw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-07-30T06:26:23Z',
#       'updatedAt': '2022-07-30T06:26:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'BracOzzRSbPqtxiTeXVTMuk00io',
#    'id': 'UgyuV39gqB2XzhyBCiB4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'mcSfd0eGlxba96FF9pSd1n4jQQs',
#      'id': 'UgyuV39gqB2XzhyBCiB4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '유희열인줄',
#       'textOriginal': '유희열인줄',
#       'authorDisplayName': '어머나얘좀봐',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_Xgr3wLT7ux1nPpoSTlkUUPQiHJFFSVkOVo4La0-J20g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCqV1QR_G57MkzoNH9RDaLXw',
#       'authorChannelId': {'value': 'UCqV1QR_G57MkzoNH9RDaLXw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-07-28T11:07:54Z',
#       'updatedAt': '2022-07-28T11:07:54Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '1fLKXUfRvNypcYjvg89O7QRm9TQ',
#    'id': 'Ugzc-St-tUu_Z-JfmpB4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'I0NAmiXZJCBcqJAZ75sn3NTtspc',
#      'id': 'Ugzc-St-tUu_Z-JfmpB4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '모두가 영상내용을 볼때 난 아이패드기종을 봤지',
#       'textOriginal': '모두가 영상내용을 볼때 난 아이패드기종을 봤지',
#       'authorDisplayName': '원혁인데요',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/dkCsTCsQVvY-SOIxkG-OwMM5ayqhak_gWhjMCNdGUm6xcInlG7sKDch9cb1wfCzh2aiKlteS5A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCZS9kuIFxxz6trco0mG9PaA',
#       'authorChannelId': {'value': 'UCZS9kuIFxxz6trco0mG9PaA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-07-27T08:39:06Z',
#       'updatedAt': '2022-07-27T08:39:06Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'bRp9tXe5Z84RGbKYdjSJPHtfAxI',
#    'id': 'UgyqvezyiHUo6kqOj014AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '2Htd4GLZI5UD17cNRY_Pb3aFqo8',
#      'id': 'UgyqvezyiHUo6kqOj014AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': 'ㅋㅋ 항상 재밌네 ㅋㅋㅋㅋㅋ',
#       'textOriginal': 'ㅋㅋ 항상 재밌네 ㅋㅋㅋㅋㅋ',
#       'authorDisplayName': '콩콩이',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/j2wXNy91LIdDb0jBDRG6eH-gD2nqXP38seqmh7vH61nAOKHBVH_Rk-8yffDsCtcvwJQ_HTTm6Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCafg83kAKQiEk58MpkJwpfw',
#       'authorChannelId': {'value': 'UCafg83kAKQiEk58MpkJwpfw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-07-26T17:35:09Z',
#       'updatedAt': '2022-07-26T17:35:09Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'fiBAY_IGTmYUos98oM9PNLjjMvg',
#    'id': 'UgxW3d4-iAMx2Cv_mol4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'U5x-_OQyRMsXRyCPX5R-oVW3r8w',
#      'id': 'UgxW3d4-iAMx2Cv_mol4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '이것이 리얼',
#       'textOriginal': '이것이 리얼',
#       'authorDisplayName': '댕이득',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-Lw1QwH40Yonurz25vPBsPrtRVWeG6psbta8yOGw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCqIfl2Q5BdRu7hg2VnQJ4jQ',
#       'authorChannelId': {'value': 'UCqIfl2Q5BdRu7hg2VnQJ4jQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-07-26T09:34:59Z',
#       'updatedAt': '2022-07-26T09:34:59Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'p_ZLbzNIq__0oMCmAr2t20l6u4o',
#    'id': 'UgympTCBZt2V6ad0Vwl4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '9bHwo14cJqtZaPhRRtZqCPqLHrA',
#      'id': 'UgympTCBZt2V6ad0Vwl4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '<a href="https://www.youtube.com/watch?v=627HBcT1jWY&amp;t=2m12s">2:12</a> 퍽유',
#       'textOriginal': '2:12 퍽유',
#       'authorDisplayName': '윌팍',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu9Z7JqchFOHXSJr0jdQknr5eAAxPMS7HR84tYaokaE=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCKjsuHBhmOHkIgVP4o4LfTQ',
#       'authorChannelId': {'value': 'UCKjsuHBhmOHkIgVP4o4LfTQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-07-25T22:38:57Z',
#       'updatedAt': '2022-07-25T22:38:57Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '1j7TAi90rzWpN8189vBZw38uyUQ',
#    'id': 'Ugz1k_h9X-ZkPzdxy-V4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'z0shlLbemWr6H9cM6GqbiOMvfDs',
#      'id': 'Ugz1k_h9X-ZkPzdxy-V4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '처음에 꽈추형인줄 ㅋㅋㅋ',
#       'textOriginal': '처음에 꽈추형인줄 ㅋㅋㅋ',
#       'authorDisplayName': '김유희',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu8Gz_PE_z3kH4jpMUGpEmLEYh5hire99QR9jq_2aA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCr_VDpA0Skg1PjuCsEdUgmg',
#       'authorChannelId': {'value': 'UCr_VDpA0Skg1PjuCsEdUgmg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-07-25T07:10:22Z',
#       'updatedAt': '2022-07-25T07:10:22Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'V29gEOKiyHPi-AEzqHoaUCu6zxg',
#    'id': 'Ugx6p7OZdGeJs8f64fx4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'C8a679nt6ztAOoTRHVmEk10yR2Y',
#      'id': 'Ugx6p7OZdGeJs8f64fx4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '진짜 배우 이준 닮으셨다 ㅋㅋㅋㅋㅋ',
#       'textOriginal': '진짜 배우 이준 닮으셨다 ㅋㅋㅋㅋㅋ',
#       'authorDisplayName': 'Juni',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ZQsKC-SzkwpDblUViAQdbKQRtTGaARX-4eDsS3saPZJqgz5HgMO9cpor98xyDzK7DHhL5vsEhg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC06-TvlERgk_vMvRQZant5g',
#       'authorChannelId': {'value': 'UC06-TvlERgk_vMvRQZant5g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-07-25T04:00:18Z',
#       'updatedAt': '2022-07-25T04:00:18Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Z00_HEDZ0iYm5SiT6y9xkihsbVo',
#    'id': 'UgxolZ15JDtgkhCwxdx4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'K1qSokjBxhRxcdLMw3STMWqhMWA',
#      'id': 'UgxolZ15JDtgkhCwxdx4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '기만같은데ㅋㅋ IT 벤처 젊은 팀장 업계지에 이름올라갈 정도의 주요 프로젝트 여유있는 태도<br>팀장이라는게 엄청 높은 직책이고 중요한 자리임. 보통 중소 벤처면 팀장=부장임. 사업부가 나눠져있는게 아니면 더더욱',
#       'textOriginal': '기만같은데ㅋㅋ IT 벤처 젊은 팀장 업계지에 이름올라갈 정도의 주요 프로젝트 여유있는 태도\n팀장이라는게 엄청 높은 직책이고 중요한 자리임. 보통 중소 벤처면 팀장=부장임. 사업부가 나눠져있는게 아니면 더더욱',
#       'authorDisplayName': 'AORUS XTREME RTX3080',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu--riPY9BnlZh7s3NYT-_wnezsremvHvNL2XWSjxw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCWojZ6xgLbNvxhN3Kjz_Zqw',
#       'authorChannelId': {'value': 'UCWojZ6xgLbNvxhN3Kjz_Zqw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-07-24T14:48:58Z',
#       'updatedAt': '2022-07-24T14:48:58Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'scgF9C8CbiSzxVTKPKcxGvChC_Q',
#    'id': 'UgwQXFhbbMMJgxUz4VF4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'QNYmaUgOosJiLuSUniCwcH8a-ug',
#      'id': 'UgwQXFhbbMMJgxUz4VF4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '와우 대사 하나하나가 현실성 쩐다 어쩜 내 생각과 똑같을까? 월급으론 영원히 티끌,빨리 시드머니로 투자하는거 20년전 제생각. 퇴사가   꿈 ^^퇴사하니 심심해요 인생은 밸런스가 중요 ㅎㅎ',
#       'textOriginal': '와우 대사 하나하나가 현실성 쩐다 어쩜 내 생각과 똑같을까? 월급으론 영원히 티끌,빨리 시드머니로 투자하는거 20년전 제생각. 퇴사가   꿈 ^^퇴사하니 심심해요 인생은 밸런스가 중요 ㅎㅎ',
#       'authorDisplayName': '워니새채널',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/YA-ZYZ4ahvQ-lsteTxYcyrd3KS15WQzO3lY6_xC8vhpJZ0-Z_iibSE5KhdI8lK4pxfqjxvrGS6c=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UChqPM1VB4EifEPAVNno9lyQ',
#       'authorChannelId': {'value': 'UChqPM1VB4EifEPAVNno9lyQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-07-24T09:04:14Z',
#       'updatedAt': '2022-07-24T09:04:14Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'GRHjODtSoaPfYcUlAVZi-7gZMwA',
#    'id': 'UgwZNHA0UlbQ_txIhGl4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'lTlN7QEZscTgqhsCae1u6Qqg6Dk',
#      'id': 'UgwZNHA0UlbQ_txIhGl4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '존나 진솔한인터뷰네',
#       'textOriginal': '존나 진솔한인터뷰네',
#       'authorDisplayName': 'IlIlI IllIIllI',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_-WQsEa-eodrwj0YdIlXCbez7PsqMig5HE7STG0A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCxcin13rVJx0vM_AO96arhQ',
#       'authorChannelId': {'value': 'UCxcin13rVJx0vM_AO96arhQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-07-24T01:10:03Z',
#       'updatedAt': '2022-07-24T01:10:03Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xpSoBztMK3RslVBRMR0ZVQAZTxQ',
#    'id': 'Ugyv0tiQa66MVmvO7g14AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'QvkExwEMNXbVWS7R4jFI2FTkXxI',
#      'id': 'Ugyv0tiQa66MVmvO7g14AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '회사 다닌지 13년... 조목조목 공감되네요 ㅋㅋㅋ &quot;능률 높이기 싫은데&quot; ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#       'textOriginal': '회사 다닌지 13년... 조목조목 공감되네요 ㅋㅋㅋ "능률 높이기 싫은데" ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#       'authorDisplayName': 'Lazy Easy Fiji Game 우울할 땐 게임을 해',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/PgNF-MNrp-gG9-Gsm_AZ_yxQK2fBh-fyr-6ZEEdn58zuLPOI01KlK9ZfJH45ZVWnEE066rDhaA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC_yWbOMYCkrUNCmd_sDNq7g',
#       'authorChannelId': {'value': 'UC_yWbOMYCkrUNCmd_sDNq7g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-07-23T02:16:07Z',
#       'updatedAt': '2022-07-23T02:16:07Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ZubMHkz5M4HgWLjBw-2DkAx7cBM',
#    'id': 'UgxsaRFWRJt0f5ol3Tx4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'OHITIZHFEHY70JcLIMGFoWJDzn8',
#      'id': 'UgxsaRFWRJt0f5ol3Tx4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '이런 식이면 절대 집 못사...',
#       'textOriginal': '이런 식이면 절대 집 못사...',
#       'authorDisplayName': 'Artmical',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_GNP-HN9UPrNe_ubnBiqQGvufWny_TbSHvsvGnGg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCiSbtzRSnxsa_adFysBCHNQ',
#       'authorChannelId': {'value': 'UCiSbtzRSnxsa_adFysBCHNQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-07-21T12:31:56Z',
#       'updatedAt': '2022-07-21T12:31:56Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'O56FP2uLTt8LT2RQSlx8RY_kGmA',
#    'id': 'UgwSwTEyu-kGwvJJ1C54AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'OkXmgOsmCkAU7PQy8W1G8oGRZPM',
#      'id': 'UgwSwTEyu-kGwvJJ1C54AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '스트라이크ㅋㅋㅋㅋㅋ 진짜 잡코 샀누 ㅋㅋㅋ',
#       'textOriginal': '스트라이크ㅋㅋㅋㅋㅋ 진짜 잡코 샀누 ㅋㅋㅋ',
#       'authorDisplayName': 'ss kim',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu9bmozQ-OqiqL5wKnBKFjLKJANwDvP5GwxAzKo3=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCQpzp2HxdUToyi78x-_GfPg',
#       'authorChannelId': {'value': 'UCQpzp2HxdUToyi78x-_GfPg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-07-21T04:39:41Z',
#       'updatedAt': '2022-07-21T04:39:41Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xQOf_YyoGcj9BM1t5cEq5GAacCY',
#    'id': 'UgxcdVa-RxKnGwwlio54AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '7NK9PGSfKGv-hbUBPmIiCostFDY',
#      'id': 'UgxcdVa-RxKnGwwlio54AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '마음의 소리가 막....나와.',
#       'textOriginal': '마음의 소리가 막....나와.',
#       'authorDisplayName': '화지진',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu8OHXLrqz0vQwoysL2Y0oGNT2JHtPtAlSnsPDpA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC0vORPudr0iHbajv98-XzYA',
#       'authorChannelId': {'value': 'UC0vORPudr0iHbajv98-XzYA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-07-10T18:04:55Z',
#       'updatedAt': '2022-07-10T18:04:55Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'vU27PcJtluPZ8uHZqnP1r2BGa7M',
#    'id': 'UgwuCySY4p5zvpQJ_bd4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'NMaqqgM9-Ru89vNU067XDcFJ3Q0',
#      'id': 'UgwuCySY4p5zvpQJ_bd4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '현재 고등학생인데 혹시 저도 대학생 되면 저렇게 변해야 되나요ㅋㅋㅋㅋㅋ 한편으론 진정성이 없게 과제를 진행하게 되는 현실이 참 아쉽네요.. 뜻 깊은 영상 감사합니다!',
#       'textOriginal': '현재 고등학생인데 혹시 저도 대학생 되면 저렇게 변해야 되나요ㅋㅋㅋㅋㅋ 한편으론 진정성이 없게 과제를 진행하게 되는 현실이 참 아쉽네요.. 뜻 깊은 영상 감사합니다!',
#       'authorDisplayName': '이여준',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-7sZbOEFTbF2p9pUG6Z9ZSj_NoWZTbHTvgH5kl=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCaQmohCICLPgOGR3m-gzBog',
#       'authorChannelId': {'value': 'UCaQmohCICLPgOGR3m-gzBog'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-07-10T12:15:50Z',
#       'updatedAt': '2022-07-10T12:15:50Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'MkBd1OFB5J1bZwfEbkf4RdGz_OM',
#    'id': 'Ugw83Ikm9LJoN6v8wpd4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'UWHELRVTygHArclN_QT5DLu1_CY',
#      'id': 'Ugw83Ikm9LJoN6v8wpd4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '와... 진짜 ㅋㅋㅋㅋㅋ 속이 뻥 ㅋㅋ',
#       'textOriginal': '와... 진짜 ㅋㅋㅋㅋㅋ 속이 뻥 ㅋㅋ',
#       'authorDisplayName': '최근호',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu8jZuhzMrDuC4e02V2sdb5I1JC3-s80IFgL_g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCkDA4b_Ovu-8VTuce59h_iA',
#       'authorChannelId': {'value': 'UCkDA4b_Ovu-8VTuce59h_iA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-07-08T05:32:01Z',
#       'updatedAt': '2022-07-08T05:32:01Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'tDO410bvWTA0JqqOrYScGVTeipU',
#    'id': 'Ugxs9rED9BI5YqmOPLd4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Ut1cUkBd5Lwd5o1wRi1qWwTZ4K0',
#      'id': 'Ugxs9rED9BI5YqmOPLd4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '유희열 특별출연',
#       'textOriginal': '유희열 특별출연',
#       'authorDisplayName': 'Ar _',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-r-UJh-tGs3CZ63_m2y9g5gnyP4C3ryxjCECxvOQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC9mp5Vc2SHNe9KwQghI-Mkw',
#       'authorChannelId': {'value': 'UC9mp5Vc2SHNe9KwQghI-Mkw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-07-05T23:56:18Z',
#       'updatedAt': '2022-07-05T23:56:18Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'K_Qrw0vBAaBplBgpjZrdAhBhQ6U',
#    'id': 'UgxTSEwqA-ytyKGAZU14AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'aLoreN0TB65AsFguBQdkxdJlLFA',
#      'id': 'UgxTSEwqA-ytyKGAZU14AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '와씨....개쩐다ㄱㄲㅋㅋㅋㅋㅋㅋ',
#       'textOriginal': '와씨....개쩐다ㄱㄲㅋㅋㅋㅋㅋㅋ',
#       'authorDisplayName': '박재훈',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/Giu8g0GUzzFX2CxwqW24f624BMx-NktY-0wnob-1yPnv7Z6E7kICH9bzrS6-vEbMoheygoqJPQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCyYOVCWM-bqqiArI2_xy4Cw',
#       'authorChannelId': {'value': 'UCyYOVCWM-bqqiArI2_xy4Cw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-06-29T04:20:07Z',
#       'updatedAt': '2022-06-29T04:20:07Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '6fsrWe35_Ss26nHAi0DmmqzoSWc',
#    'id': 'UgytmKfckUfVhlo3f-x4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'UaYvRk5G2tdf3K-oofPfLgd809A',
#      'id': 'UgytmKfckUfVhlo3f-x4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '코스닥  노터스 사라, 담주 부터 쏜다.',
#       'textOriginal': '코스닥  노터스 사라, 담주 부터 쏜다.',
#       'authorDisplayName': 'ADMIRAL BLUE애드머럴 블루',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu95I7kTniIu7nDmhEsSF4uCZybv2bfSCtWHmNTGSg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCZzGP6ryCrz1-lBeEARQwgQ',
#       'authorChannelId': {'value': 'UCZzGP6ryCrz1-lBeEARQwgQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-06-25T14:52:41Z',
#       'updatedAt': '2022-06-25T14:52:41Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '_nL9f7hm_-046WZr_Qs7l9_Y6Mc',
#    'id': 'UgyGVwUT8ig1jG-8m3V4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Yrqs0osMZTSjl8gWcBI2jsmKmOc',
#      'id': 'UgyGVwUT8ig1jG-8m3V4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '<a href="https://www.youtube.com/watch?v=627HBcT1jWY&amp;t=1m59s">1:59</a>',
#       'textOriginal': '1:59',
#       'authorDisplayName': '바둑',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/HCaLjRbH82yRk1Gi7s1zVOOfBXhBHrjElgTqfg8b244Zz3e3w8wwMVzwZ5-iO_e3LhFHVVTzeg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCyMeOI1G6P_ikE5lHLyVykg',
#       'authorChannelId': {'value': 'UCyMeOI1G6P_ikE5lHLyVykg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-06-24T08:59:47Z',
#       'updatedAt': '2022-06-24T08:59:47Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '5Itm6CYQcPDBWT_XgTCfbk5mBT0',
#    'id': 'Ugz2SMDXy6EzsgTLo5d4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'swL_j07_XMYMO8-IWOWVW-00qXU',
#      'id': 'Ugz2SMDXy6EzsgTLo5d4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '와… 직장생활 시절 저의 모습같아여. ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#       'textOriginal': '와… 직장생활 시절 저의 모습같아여. ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#       'authorDisplayName': '봄이왔섭',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/IwTXsz7niWwGVE0TQcDyX5wFjLQ9O996LtLWyKavsvFiRH2mO279xHAbxAFnE-KHxT7o-5kw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC5Nb19IQsUKpYvG-B3toYew',
#       'authorChannelId': {'value': 'UC5Nb19IQsUKpYvG-B3toYew'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-06-16T14:21:17Z',
#       'updatedAt': '2022-06-16T14:21:17Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'OE-n0h-KiojhMYH-bJA-6SdNtA0',
#    'id': 'UgxmyL5sGKwVZPF5Ovt4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'TJ8alXS_zyx6zD83wJtp9i06gp0',
#      'id': 'UgxmyL5sGKwVZPF5Ovt4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '퇴사 생각은 늘 든다',
#       'textOriginal': '퇴사 생각은 늘 든다',
#       'authorDisplayName': 'JkT',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-jcpD_hthacvWi0h7iob-gwoge2EXBBDbYIO9SQyoOEzhMwBoshttvHGdLMhgq=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCmF3g0-5PBpiBtTu5cg9_dg',
#       'authorChannelId': {'value': 'UCmF3g0-5PBpiBtTu5cg9_dg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-06-15T22:54:19Z',
#       'updatedAt': '2022-06-15T22:54:19Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '3rHRrezg1ngEDa0gVEdXXGOrjRw',
#    'id': 'Ugzq0EuvXJYGRii3ajx4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'GSAN_ilHewkwiefPvV1N2bAKmEA',
#      'id': 'Ugzq0EuvXJYGRii3ajx4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '아ㅋㅋㅋㅋ미쳤냐고ㄲㅋㅋㅋㅋ현실고증ㅋㅋㅋㅋㄱㅋㅋ',
#       'textOriginal': '아ㅋㅋㅋㅋ미쳤냐고ㄲㅋㅋㅋㅋ현실고증ㅋㅋㅋㅋㄱㅋㅋ',
#       'authorDisplayName': '쿠쿠',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu8eRaoDTHrbAbZ_ZRdv71gSwIBZ-46UUSESFk937sEHGCoeflqoxbleXQf4p4XQzNmgnxs=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCpgVPv6eNyVNRH2KJgn7uCg',
#       'authorChannelId': {'value': 'UCpgVPv6eNyVNRH2KJgn7uCg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-06-09T10:48:52Z',
#       'updatedAt': '2022-06-09T10:48:52Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'eozI0KtUP_taUi6-ZkK0K7o9qW4',
#    'id': 'UgyMcGwt3XrhA7ZzD2x4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'WJOX73FeW7RVGWgbtoUicXEFAaM',
#      'id': 'UgyMcGwt3XrhA7ZzD2x4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '인터뷰어는 직업의식 100%인데 ㅋㅋㅋㅋㅋ',
#       'textOriginal': '인터뷰어는 직업의식 100%인데 ㅋㅋㅋㅋㅋ',
#       'authorDisplayName': '박광진',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu9GzBu6wxoVvp8K8FmW5LLVFQaii_j2qeWaQLkmIUH5dA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCv3IAsuwdMMrZvf6jjLxffg',
#       'authorChannelId': {'value': 'UCv3IAsuwdMMrZvf6jjLxffg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-06-07T01:56:38Z',
#       'updatedAt': '2022-06-07T01:56:38Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'JJjJg6BYQHaIWjhjPGZHhVQlnkM',
#    'id': 'UgznayaH-Kis8YL2ZxB4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'vsDMTI1uT--iJJaaAJy7dDBpUfw',
#      'id': 'UgznayaH-Kis8YL2ZxB4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '가끔보러옵니다<br>넘 재밋어요 이거<br>ㅋㅋㅋ',
#       'textOriginal': '가끔보러옵니다\n넘 재밋어요 이거\nㅋㅋㅋ',
#       'authorDisplayName': 'Sara',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu9aEHg2baygBjHG6X3_oYGsEDeOQafmrcFQTq2I77o=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC_FI7h-35OHHfQoiQlw_mNg',
#       'authorChannelId': {'value': 'UC_FI7h-35OHHfQoiQlw_mNg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2,
#       'publishedAt': '2022-06-06T09:27:30Z',
#       'updatedAt': '2022-06-06T09:27:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'jKMdZyYh-vPoMW80JzjEAqfBOwI',
#    'id': 'UgymcEfRz8yt9wmBEtV4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'UppRlTA0vTvB2Z_uKJKOgPdvWKw',
#      'id': 'UgymcEfRz8yt9wmBEtV4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '😃',
#       'textOriginal': '😃',
#       'authorDisplayName': 'ᄏᄏ',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_xN4I7tBz9Z5EYhXlCCu4R81hHnhPFEVMR_tlGrA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCx__OHnhFUUbN0BQ8o1BJwQ',
#       'authorChannelId': {'value': 'UCx__OHnhFUUbN0BQ8o1BJwQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-06-06T07:59:51Z',
#       'updatedAt': '2022-06-06T07:59:51Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '0PFleEN12W717w7nY4qxGiKqlZU',
#    'id': 'UgzHMG-oCdLq_k1LCpZ4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'QfCQGqQ463IEuIenl4IAjHPWZ-E',
#      'id': 'UgzHMG-oCdLq_k1LCpZ4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '와 진짜 너무 현실적이다 이편',
#       'textOriginal': '와 진짜 너무 현실적이다 이편',
#       'authorDisplayName': '현',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu9GXvU-hQtg5QkZ-rE8EQGlOgeZxvxqYEqMPtmeyg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCYeHCxZTKM-WzG0VVbWcSBQ',
#       'authorChannelId': {'value': 'UCYeHCxZTKM-WzG0VVbWcSBQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-06-06T07:39:32Z',
#       'updatedAt': '2022-06-06T07:39:32Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Vty6NX66Qly5Gg-HgrxDvifHHTs',
#    'id': 'Ugxj1lZBDgmEPlCkORt4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'seCS6dZhlwsxktulSkLRnAk8iZM',
#      'id': 'Ugxj1lZBDgmEPlCkORt4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '주식 까보는거 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#       'textOriginal': '주식 까보는거 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#       'authorDisplayName': '바람과돌',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu8QDZyVR6XfvAVpOdrfTAzSU_0PuLzD5zkQKMm-=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCtreJgf5Bptt-UCjOGQ0B3g',
#       'authorChannelId': {'value': 'UCtreJgf5Bptt-UCjOGQ0B3g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-06-05T09:53:37Z',
#       'updatedAt': '2022-06-05T09:53:37Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'PwTrZiL9fiNhy_5bhF9528r24P4',
#    'id': 'UgzQmMIgIQuB4tU0ZnB4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'AIrLLHZlyFYA_CPTS0pz6cPt6gU',
#      'id': 'UgzQmMIgIQuB4tU0ZnB4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '와 ㄹㅇㅋㅋㅋ 나같네ㅋㅋ 아무도 팀장 안 할려고 해서ㅋㅋㅋㅋ 억지로 됐는데 책임지고 늦게까지 일하는건 기본인데 오른 월급이ㅋㅋㅋ 좃소라 그런가 10만원만 오름...^^<br>다 때려치고 지금은 좋은 대표님 만나서 샌드위치날은 펑펑 쉬고 월급은 월급대로 그때랑 똑같이 받음<br>진짜 좃소는 못 고침 책임도 올라가고 그만큼 일을 더 많이 하는건데 그럼 월급이나 팍팍 올리던가 왜 월급은 제자리 걸음임<br>그놈의 인건비ㅋㅋ 그래서 그거 아끼면 그 놈의 회사가 얼마나 갈 거 같냐?ㅋㅋ',
#       'textOriginal': '와 ㄹㅇㅋㅋㅋ 나같네ㅋㅋ 아무도 팀장 안 할려고 해서ㅋㅋㅋㅋ 억지로 됐는데 책임지고 늦게까지 일하는건 기본인데 오른 월급이ㅋㅋㅋ 좃소라 그런가 10만원만 오름...^^\n다 때려치고 지금은 좋은 대표님 만나서 샌드위치날은 펑펑 쉬고 월급은 월급대로 그때랑 똑같이 받음\n진짜 좃소는 못 고침 책임도 올라가고 그만큼 일을 더 많이 하는건데 그럼 월급이나 팍팍 올리던가 왜 월급은 제자리 걸음임\n그놈의 인건비ㅋㅋ 그래서 그거 아끼면 그 놈의 회사가 얼마나 갈 거 같냐?ㅋㅋ',
#       'authorDisplayName': '류하연',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/JiXsqzodp1urNgUobttFryNn6uW2i1CQSCeAAEDmtZswJTd8IZT7ZpjDzCoamwtpgwSAp3QF1hA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCfbM85IcJOiANXzjQ3vo3Iw',
#       'authorChannelId': {'value': 'UCfbM85IcJOiANXzjQ3vo3Iw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-06-05T00:03:37Z',
#       'updatedAt': '2022-06-05T00:03:37Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'tdOMV9lFskKompyfckQgYrcBJvI',
#    'id': 'Ugz9jTk4loszrC7YYuB4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'CqnZU_3sS-e3kassjM-AjV8gZqQ',
#      'id': 'Ugz9jTk4loszrC7YYuB4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '블랙코메디네',
#       'textOriginal': '블랙코메디네',
#       'authorDisplayName': 'orion s',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_W36I4miZnJ3UFZGgam-Vf74TJBtXdp0_r6oNPmw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCyPTZBOsq-_almzNjCI4jHQ',
#       'authorChannelId': {'value': 'UCyPTZBOsq-_almzNjCI4jHQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-06-04T12:05:03Z',
#       'updatedAt': '2022-06-04T12:05:03Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'yG8MvJc0J3Crjr3FLV1jfcKQrMI',
#    'id': 'Ugy0a3KSuxZsxE2O6M94AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'xMNL5maqQPFEs0r_K6SuLzxSyh4',
#      'id': 'Ugy0a3KSuxZsxE2O6M94AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '반말 하지맠ㅋㅋㅋㅋㅋㅋ',
#       'textOriginal': '반말 하지맠ㅋㅋㅋㅋㅋㅋ',
#       'authorDisplayName': '전민경',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_9aE50KkC4jSU8Z5Faca7QH1hzzNWp5IX1sA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCgxXW-0NoDEfd9rk5_zM-cQ',
#       'authorChannelId': {'value': 'UCgxXW-0NoDEfd9rk5_zM-cQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2,
#       'publishedAt': '2022-06-04T09:40:44Z',
#       'updatedAt': '2022-06-04T09:40:44Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'sy65SelqXYgu-vSGTIehmwp9bTk',
#    'id': 'UgyXgpcWd2iUALkub1x4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'MGtxRTx5uaox0UJzlypL5xzzI8I',
#      'id': 'UgyXgpcWd2iUALkub1x4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '<a href="https://www.youtube.com/watch?v=627HBcT1jWY&amp;t=0m06s">0:06</a> 떨어지고 있어 ㅠ',
#       'textOriginal': '0:06 떨어지고 있어 ㅠ',
#       'authorDisplayName': 'SS_newbie ',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/Bg7PgWW8pHgttbF83OQry8ITDQyD3Zd4USaCwjhCGDzCi0SMksHUskp1jHNxwpbkHCR6o8NPTg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCJAtj4rURMAS-DfneSW5oTg',
#       'authorChannelId': {'value': 'UCJAtj4rURMAS-DfneSW5oTg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-06-02T09:49:08Z',
#       'updatedAt': '2022-06-02T09:50:01Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'KrWR2L2CM73MxuEJgoqPQFACa_o',
#    'id': 'Ugxe3eYEHvqZG_jYJPx4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'nnutWLzorizyFmfbMJ_Cw6I1dtg',
#      'id': 'Ugxe3eYEHvqZG_jYJPx4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '5틱 시발 ㅋㅋㅋ',
#       'textOriginal': '5틱 시발 ㅋㅋㅋ',
#       'authorDisplayName': 'caesar',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/4Yy1U23wdw8CKNjd6bPVUp5fIELQ3MzkWYzj4HZH9VYDzZHznWIzTgZiFq3INICJeOgA9iZ0jA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCt63WWLfWq3b5nphYnx9jNg',
#       'authorChannelId': {'value': 'UCt63WWLfWq3b5nphYnx9jNg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-05-30T17:15:46Z',
#       'updatedAt': '2022-05-30T17:15:46Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'q4ToHpogf4vU5GgiD38D-xTSSIM',
#    'id': 'UgxvvDSvi4O4FjAhDs54AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
# ...
#       'textDisplay': '시드머니 중요',
#       'textOriginal': '시드머니 중요',
#       'authorDisplayName': '라망',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-gLop1xLSgqf9PJ-A-lF9g4_A1HKFy_uOJ_on-Fw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCVfxHUYLw9sGyAlIgscZ1TA',
#       'authorChannelId': {'value': 'UCVfxHUYLw9sGyAlIgscZ1TA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-05-06T08:27:36Z',
#       'updatedAt': '2022-05-06T08:27:36Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '7CI8CbMgQve5cPa7E-PdF6f5sjk',
#    'id': 'UgydbTw6jB-nlY4uKnR4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'nUgnsU3ijKvdY6XAldH84sUU1Jg',
#      'id': 'UgydbTw6jB-nlY4uKnR4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '자막도 넣어주셔서 청각장애인 있는 분들도 보기 편하네영',
#       'textOriginal': '자막도 넣어주셔서 청각장애인 있는 분들도 보기 편하네영',
#       'authorDisplayName': 'LOVE conguers all',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu8uWyAkudP8_qFfnO8GxrAbA7q7RvQLbQf3fFSLrw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC2NtSV4qve8pD_E4ozSOXrQ',
#       'authorChannelId': {'value': 'UC2NtSV4qve8pD_E4ozSOXrQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-05-04T15:38:19Z',
#       'updatedAt': '2022-05-04T15:38:19Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'NUiamc8HL4kVfsXznP6ANFzNaJI',
#    'id': 'UgzylEcRHp9-ydPRSlR4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'EKVvEH2ww_z47VChNbreUqKvceE',
#      'id': 'UgzylEcRHp9-ydPRSlR4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '와 유현규표저유진짜 킹받네 ㅋㅋㅋㅋ',
#       'textOriginal': '와 유현규표저유진짜 킹받네 ㅋㅋㅋㅋ',
#       'authorDisplayName': '박사장뉨',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu9inDZPIwgtFAcZ8XupJCWYI3azEvEoIA-t1wYaHQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC3w-8JJCVwntdleLtUwyPsw',
#       'authorChannelId': {'value': 'UC3w-8JJCVwntdleLtUwyPsw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-05-04T14:28:49Z',
#       'updatedAt': '2022-05-04T14:28:49Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'OdYXzFoV3z9e1ea5wdMd-RFrMVE',
#    'id': 'UgwgIuvg3tLLEO_seZx4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'HplFXcBCn3TIT_PZ4qL3RK2_gOI',
#      'id': 'UgwgIuvg3tLLEO_seZx4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '5월입니다 스트라이크 그냥두세요 4만넘었네요 네 수고.',
#       'textOriginal': '5월입니다 스트라이크 그냥두세요 4만넘었네요 네 수고.',
#       'authorDisplayName': 'BJ',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/KHvB3bE2gIIegTR2Mzdhpud-wNzuvLKDJUZG_HjK-hr0tfoVRphyuEst5O0B4Og7L8-UGfQpNFA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCfqFa9zp_zWK3zVPWsULzeA',
#       'authorChannelId': {'value': 'UCfqFa9zp_zWK3zVPWsULzeA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-05-02T05:22:38Z',
#       'updatedAt': '2022-05-02T05:22:38Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '3ZjpRCYieXHniZS-ev1BzlZlhbo',
#    'id': 'Ugw1J2cucoL8JiPQwzx4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'nMO6n7dkLmeWmYYc0uXjt9TLYCE',
#      'id': 'Ugw1J2cucoL8JiPQwzx4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '그 일만 많아지고 돈도 그대론데 그걸 누가 할라 그래 &quot;아 내가 하고 있구나&quot; ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#       'textOriginal': '그 일만 많아지고 돈도 그대론데 그걸 누가 할라 그래 "아 내가 하고 있구나" ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#       'authorDisplayName': '행복한오징어',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu8UPuKTaDIsIT_y6BTm6z1YtKck1WKExWV-_IEsQg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UClkD9EJqlUgZ0fh-n8bukwA',
#       'authorChannelId': {'value': 'UClkD9EJqlUgZ0fh-n8bukwA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-04-30T14:11:33Z',
#       'updatedAt': '2022-04-30T14:11:33Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '4nYgvXHYn-Ofgvf1_FHS1d8FB7o',
#    'id': 'UgxvUi3t9FMEYlAztUZ4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'T-wvllv_ktTXgGxDED8ySgQXrWc',
#      'id': 'UgxvUi3t9FMEYlAztUZ4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '시드머니 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#       'textOriginal': '시드머니 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#       'authorDisplayName': '언젠가는',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/y5MVWnGZ2k1KRNKcoUgkypHeVBQATK4YXeJNEi7D8EklMmAkb7Kp19ZzNcvK66r16k2wsvlSqg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCOsp05IbcEKJPc7DSGZrx1w',
#       'authorChannelId': {'value': 'UCOsp05IbcEKJPc7DSGZrx1w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-04-29T10:18:38Z',
#       'updatedAt': '2022-04-29T10:18:38Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'gjdDGxyIqSznj1rjifulbQxtvVw',
#    'id': 'UgxIFJdIqkL-co941sZ4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'haUyGuHwQ0yLXvM0bYFUM_hFtqc',
#      'id': 'UgxIFJdIqkL-co941sZ4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': 'PD역할 하신분 피부 진짜 좋다',
#       'textOriginal': 'PD역할 하신분 피부 진짜 좋다',
#       'authorDisplayName': 'snow_ flower_',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ETQ2Dh21BSo6x8bbFJ-_P_GCmynSrCRG9rfKs0r0Q36lE5eeWtgq3-GT_PTup_aYfTqFR_8rzio=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCLEgCCUN4Ks20XzCmH10SAw',
#       'authorChannelId': {'value': 'UCLEgCCUN4Ks20XzCmH10SAw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-04-28T14:26:35Z',
#       'updatedAt': '2022-04-28T14:26:35Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ix5urZuw4sZIMhQVo7BsF-IJ_X4',
#    'id': 'UgzJt-nAJNWbmBSagxd4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '-QDtQTh7ylIobGb0V2Xnn-TEtM8',
#      'id': 'UgzJt-nAJNWbmBSagxd4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': 'ㅋㅋㅋㄱㅋㅋ 재밌군ㅋㅋ',
#       'textOriginal': 'ㅋㅋㅋㄱㅋㅋ 재밌군ㅋㅋ',
#       'authorDisplayName': '블루',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu8888clP0YN7YosYsxww-4-QMHacLq--Vfq9Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCy2ktoalNlqQ406koyw5JQQ',
#       'authorChannelId': {'value': 'UCy2ktoalNlqQ406koyw5JQQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-04-28T09:29:27Z',
#       'updatedAt': '2022-04-28T09:29:27Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'UfHKJy_ASRIhGMHvZpyNp3g9PNM',
#    'id': 'Ugwi8P19ONbxhXJC1nR4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'a_f9jWJDn1rxhjDzxEjLpSnljy8',
#      'id': 'Ugwi8P19ONbxhXJC1nR4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '저사람들 노려보는 눈빛 너무좋아 ㅋㅋㅋ',
#       'textOriginal': '저사람들 노려보는 눈빛 너무좋아 ㅋㅋㅋ',
#       'authorDisplayName': 'life of ys',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-AtrQEglR-Cch1f1dklBjyE056RDiM8-cNl_jzzEXxcxFCwMbH9mSWTbogtEqh=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCQCippSm89-OTlPK1qzz0EQ',
#       'authorChannelId': {'value': 'UCQCippSm89-OTlPK1qzz0EQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-04-27T11:18:24Z',
#       'updatedAt': '2022-04-27T11:18:24Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'jyHiHnN_z0hdIFC3OQD0MpXqCfM',
#    'id': 'UgxX3nXJJZXFi-d82wp4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'xRBxZKdsGhnBR33qJFV2yviv5EE',
#      'id': 'UgxX3nXJJZXFi-d82wp4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '너무재밌네 ㅎㅎㅎ 흥하세요🙋🏻\u200d♀️',
#       'textOriginal': '너무재밌네 ㅎㅎㅎ 흥하세요🙋🏻\u200d♀️',
#       'authorDisplayName': '본투비레이지',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu9Nk9zFXfe7k2abkdQJhKBPNEkDS4ntt6anew=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCRkZQX8ccxTIpNWj-quBfLQ',
#       'authorChannelId': {'value': 'UCRkZQX8ccxTIpNWj-quBfLQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-04-27T10:29:32Z',
#       'updatedAt': '2022-04-27T10:29:32Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'XtnWq86I7fgqQuKBlNqn54OmBjA',
#    'id': 'UgxOYpsiJSLwtFEfujJ4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'EnzQ1kZ5XAITQNk2A9KY0ycAAo8',
#      'id': 'UgxOYpsiJSLwtFEfujJ4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '고생끝에 골병난다에서 개뿜었네 ㅅㅂㅋㅋㅋㅋㅋㅋㅋ',
#       'textOriginal': '고생끝에 골병난다에서 개뿜었네 ㅅㅂㅋㅋㅋㅋㅋㅋㅋ',
#       'authorDisplayName': '김형찬',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/pfTARk-KEhkfg0eUs4HttNEMSN04VyvfERpdqA57OwBhuX_x-VN9ZuwGFx6ssP6-K2tivLrZDg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCXVoXTOz3BuE0EtdVJwB21Q',
#       'authorChannelId': {'value': 'UCXVoXTOz3BuE0EtdVJwB21Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-04-27T08:21:58Z',
#       'updatedAt': '2022-04-27T08:21:58Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Tld9BdUlrCOWObxqOyPJ_y8omrs',
#    'id': 'UgyzpRWAiUCNYT9uMep4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'vnp_AM89aiKvJnjX-hZ_AeTfOjU',
#      'id': 'UgyzpRWAiUCNYT9uMep4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '태어나서 카풀어플로 벤츠 딱 한번 타봤는데 그 분도 티끌은 모아봐야 티끌이다 편하게 살라했던게 생각나네',
#       'textOriginal': '태어나서 카풀어플로 벤츠 딱 한번 타봤는데 그 분도 티끌은 모아봐야 티끌이다 편하게 살라했던게 생각나네',
#       'authorDisplayName': '따따',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu9B23kO-2hP80c9ykjTIP5gyyaFqHEawUzOyrmMGwNurk0SDA9Q-Rha3ppM5naVNqVovVE=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCCePYpnp2wHTmcllp2lSwVw',
#       'authorChannelId': {'value': 'UCCePYpnp2wHTmcllp2lSwVw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-04-26T19:41:11Z',
#       'updatedAt': '2022-04-26T19:41:11Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '384NLKc97zY7jz80j_mEeRMfuNM',
#    'id': 'UgxR75BujcDVonqzYWp4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'lnizRidmL61_V2qHFz-EBM59Yg8',
#      'id': 'UgxR75BujcDVonqzYWp4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': 'ㅋㅋㅋㅋ 인터뷰 끝나니까 목소리 겁나 가라앉아ㅋㅋㅋㅋ 대학생도 대학이라는 곳에서 나름대로 살아남기 위해 가면쓰고 과제중이었엉ㅋㅋ 생각해보면 학생도 대학생도 직장인도 쉬운 단계는 없는 것 같아요',
#       'textOriginal': 'ㅋㅋㅋㅋ 인터뷰 끝나니까 목소리 겁나 가라앉아ㅋㅋㅋㅋ 대학생도 대학이라는 곳에서 나름대로 살아남기 위해 가면쓰고 과제중이었엉ㅋㅋ 생각해보면 학생도 대학생도 직장인도 쉬운 단계는 없는 것 같아요',
#       'authorDisplayName': 'windvoice22',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_ltJlx3-vCIHimBYSeVY0bgMPQAN-R1-C_iw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCmJsEU1-CdSTfdZZPmVJiZg',
#       'authorChannelId': {'value': 'UCmJsEU1-CdSTfdZZPmVJiZg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 12,
#       'publishedAt': '2022-04-26T05:17:27Z',
#       'updatedAt': '2022-04-26T05:17:27Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'abAUDfpVptpYwJQUNeDPLTY6efg',
#    'id': 'UgxA0WxOegYKgu7AyrF4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'eH1J0ZYeddDckU2VYi0EfUheuGg',
#      'id': 'UgxA0WxOegYKgu7AyrF4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '<a href="https://www.youtube.com/watch?v=627HBcT1jWY&amp;t=2m13s">2:13</a> 손가락 디테일 보소 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#       'textOriginal': '2:13 손가락 디테일 보소 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#       'authorDisplayName': 'Dick Man',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu8QCp4Lk-MWtyCT1rVFc1tv9GGEHzWMb-7MZXz5tlAdraAQbu0nIxf0-sRoEGoZ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCTpFzDStoAmnHoTlaFP_MYw',
#       'authorChannelId': {'value': 'UCTpFzDStoAmnHoTlaFP_MYw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-04-25T09:27:21Z',
#       'updatedAt': '2022-04-25T09:27:21Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'TOs3Pxx2wuahg0fDIkeHXrCieNw',
#    'id': 'UgxBy-LFbInDDdwXJVl4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'JZZ9REIGt7__wzzmxfEs4iEPkk8',
#      'id': 'UgxBy-LFbInDDdwXJVl4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '현실적으로... 쩝 ㅠ',
#       'textOriginal': '현실적으로... 쩝 ㅠ',
#       'authorDisplayName': '김기범',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_aR14M09PWhKLXA1Ot9HJS9dB-LrDB6EEdjg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC6t1nUpcgfubGs94jqewzww',
#       'authorChannelId': {'value': 'UC6t1nUpcgfubGs94jqewzww'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-04-25T09:06:46Z',
#       'updatedAt': '2022-04-25T09:06:46Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'NQhewPjVT0z3PB-CPrxHRjUpXiw',
#    'id': 'UgwhMRTVbQruJyNcH8F4AaABAg',
#    'snippet': {'videoId': '627HBcT1jWY',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '4oH0dH-HXlronyVX-Z290wKAMek',
#      'id': 'UgwhMRTVbQruJyNcH8F4AaABAg',
#      'snippet': {'videoId': '627HBcT1jWY',
#       'textDisplay': '진짜 명작이다👏👏👏',
#       'textOriginal': '진짜 명작이다👏👏👏',
#       'authorDisplayName': '계정',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-8uBUkylVLL0OXS8AVR-wxBWBIAHB0HJYu4g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCsPH4PnHh1ifA65I9G6EKGw',
#       'authorChannelId': {'value': 'UCsPH4PnHh1ifA65I9G6EKGw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-04-24T23:59:11Z',
#       'updatedAt': '2022-04-24T23:59:11Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %%
while response = (
    youtube
    .commentThreads()
    .list(
      part='snippet,replies', 
      videoId='eacvvczvPLo', 
      maxResults=100
      )
    .execute()
    )
response

# %%
list5=[]
videoiddata=''
def youtube_comments(list5, videoiddata):
    response=(
            youtube
            .commentThreads()
            .list(
            part='snippet,replies', 
            videoId= videoiddata, 
            maxResults=100
            )
        .execute()
        )
    while response.get('nextpageToken'):
        response=(
                youtube
                .commentThreads()
                .list(
                part='snippet,replies', 
                videoId=videoiddata, 
                pageToken=response.get('nextPageToken'),
                maxResults=100
                )
            .execute()
            )
    return [response.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('textOriginal') for i in range(len(response.get('items')))]

# %%
print(youtube_comments([],'627HBcT1jWY'))
# Out:
# ["이게 그 '소심한 복수'랑 이어지네 ㅋㅋㅋㅋ", '여러번 지나가다 뜰때마다 다시보는 중인데 오늘은 문득...그 타로랑 비슷해보임 ㅎㅎㅎ', '이게 ㄹㅇ 명작이다..', "Honestly, ever since I started watching Kdramas, I'm amazed at how great Korean actors are. I mean, these guys here do it just for kicks on YouTube and they're better than actual actors in my country 🤣😭", 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ팀장 아무도 하기 싫어해서ㅌㅌㅋㅋㅌ', '02:58 이때 팔걸...', '팀장님... 난가??', '철저히 꿈도 희망도 없는 영상.', '아 ㅆ 내얘긴가ㅋㅋㅋㅋㅋㅋㅋ', '카페에 누가 올려주신 당근마켓 보고 순례중입니다. 물론 구독과 좋아요도 잊지 않았습니다. 와......작년 12월?에 10만 감사 영상 찍으셨던데 132만......ㄷㄷ 자주 올게요!', '정치인들 CEO들이 진심으로 하고 싶어하는말을 진실대로 말해주니까 100점', '정말 표현력이 좋으신거 같습니다. 영상들나하나 정말 퀄리티가 높은 거 같아요 이런 소재들을 항상 재미있게 풀어주시는 너덜트 님께 감사드립니다. 좋은 영상 항상 감사합니다.', '썸넬: 유희열?', '유희열인줄', '모두가 영상내용을 볼때 난 아이패드기종을 봤지', 'ㅋㅋ 항상 재밌네 ㅋㅋㅋㅋㅋ', '이것이 리얼', '2:12 퍽유', '처음에 꽈추형인줄 ㅋㅋㅋ', '진짜 배우 이준 닮으셨다 ㅋㅋㅋㅋㅋ', '기만같은데ㅋㅋ IT 벤처 젊은 팀장 업계지에 이름올라갈 정도의 주요 프로젝트 여유있는 태도\n팀장이라는게 엄청 높은 직책이고 중요한 자리임. 보통 중소 벤처면 팀장=부장임. 사업부가 나눠져있는게 아니면 더더욱', '와우 대사 하나하나가 현실성 쩐다 어쩜 내 생각과 똑같을까? 월급으론 영원히 티끌,빨리 시드머니로 투자하는거 20년전 제생각. 퇴사가   꿈 ^^퇴사하니 심심해요 인생은 밸런스가 중요 ㅎㅎ', '존나 진솔한인터뷰네', '회사 다닌지 13년... 조목조목 공감되네요 ㅋㅋㅋ "능률 높이기 싫은데" ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '이런 식이면 절대 집 못사...', '스트라이크ㅋㅋㅋㅋㅋ 진짜 잡코 샀누 ㅋㅋㅋ', '마음의 소리가 막....나와.', '현재 고등학생인데 혹시 저도 대학생 되면 저렇게 변해야 되나요ㅋㅋㅋㅋㅋ 한편으론 진정성이 없게 과제를 진행하게 되는 현실이 참 아쉽네요.. 뜻 깊은 영상 감사합니다!', '와... 진짜 ㅋㅋㅋㅋㅋ 속이 뻥 ㅋㅋ', '유희열 특별출연', '와씨....개쩐다ㄱㄲㅋㅋㅋㅋㅋㅋ', '코스닥  노터스 사라, 담주 부터 쏜다.', '1:59', '와… 직장생활 시절 저의 모습같아여. ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '퇴사 생각은 늘 든다', '아ㅋㅋㅋㅋ미쳤냐고ㄲㅋㅋㅋㅋ현실고증ㅋㅋㅋㅋㄱㅋㅋ', '인터뷰어는 직업의식 100%인데 ㅋㅋㅋㅋㅋ', '가끔보러옵니다\n넘 재밋어요 이거\nㅋㅋㅋ', '😃', '와 진짜 너무 현실적이다 이편', '주식 까보는거 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '와 ㄹㅇㅋㅋㅋ 나같네ㅋㅋ 아무도 팀장 안 할려고 해서ㅋㅋㅋㅋ 억지로 됐는데 책임지고 늦게까지 일하는건 기본인데 오른 월급이ㅋㅋㅋ 좃소라 그런가 10만원만 오름...^^\n다 때려치고 지금은 좋은 대표님 만나서 샌드위치날은 펑펑 쉬고 월급은 월급대로 그때랑 똑같이 받음\n진짜 좃소는 못 고침 책임도 올라가고 그만큼 일을 더 많이 하는건데 그럼 월급이나 팍팍 올리던가 왜 월급은 제자리 걸음임\n그놈의 인건비ㅋㅋ 그래서 그거 아끼면 그 놈의 회사가 얼마나 갈 거 같냐?ㅋㅋ', '블랙코메디네', '반말 하지맠ㅋㅋㅋㅋㅋㅋ', '0:06 떨어지고 있어 ㅠ', '5틱 시발 ㅋㅋㅋ', '이거지.. 이거야', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '2:11 뻐큐 날리네 ㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋ 진심이네 ㅋㅋ', '2:12 깨알 mln', '워라벨 없으면 돈이라도 챙겨야지 진짜 공감.. 구구절절 다 공감 ㅋㅋㅋㅋㅋㅋ 잡코인 보고 있는 것도 ㅋㅋㅋ', '뻑규 디테일 ㅋㅋ', '일찍 일어나는 새가 피곤하다 ㅆㅇㅈ ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ\n숙면 1시간 차이로 하루 전체의 컨디션이 결정됨.\n직장에서 집 가까운 사람이 능률이 좋은 이유.', '일찍 일어나는 새가 피곤하닼ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '허를 찌르는 연출', '지루할 틈이 없음 ㅋㅋㅋ', '주옥같은 띵언 파티 ㅋㅋㅋ 즐길 수 없으면 피해라 일찍 일어나는 새가 피곤하다 존재 가치 증명 왕관 쓰고 싶지 않은데 ?', '3분만 더 있다 가', '자연스러운 생활연기 ㅋㅋㅋ 팀장이 인터뷰할 때 고생 끝에 골병 든다? 이런식으로 눈 풀리면서 말하는 씬 술 한잔 걸치고 찍으신 거 아니죠? 합리적 의심', '기자가 더 똑똑해보여요. 그러나 저도 시드머니 모아 불려 평일에 낮잠자는게 소원이네용 ㅎㅎ', '나중에 하고 싶은 거 있어요?\n여기서 나가는 거요 \n\nㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 킬포야 진짜 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '지극히 "현실"적인 인터뷰ㅋㅋㅋㅋㅋㅋㅋㅋ', '연기력 쩐다~~~', '주기적으로 보러오는데 항상 새로워요 ㅋㅋㅋㅋ', 'ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ', '문 도 안 닫.', '와 대학생이었어 ㅋㅋ 생각지 못했던 반전의 내용 ㅎㅎ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '2:13 은근슬쩍 ㅗ', '반말하지마... 대박이다ㅋㅋㅋㅋ', '회사 명언을 깨알같이 준비했군요 ,,,  너덜트 멋지다요 ~~', '마스크랑 안경 쓰니까 꽈추형 닮았네 ㅋㅋㅋ', '거의 마지막에 안경 중지로 올리는거 ㅋㅋㅋ', '어제보다 나은 내일은 토요일이다...', '명언이 다 박명수어록 ㅋㅋㅋㅋㅋㅋㅋ', '일찍 일어난 새가 벌레를 잡아 먹는다\n일찍 일어난 벌레는 새에게 더 빨리 잡아먹힌다', '썸네일 류승룡..?!', '레알 취직하기 전까진 몰랐는데 악착같이 돈 벌어야 되는 이유는 이딴 회사에서 탈출하기 위해서. 능력을 기르면 우대한다? 능력좋은 노예가 될 뿐임. 돈이 최고다. 빨리 벌어서 투자해라 어디든.', '와 마지막까지 ㅋㅋㅋㅋㅋㅋ', '2:12 뻑큐 ㅋㅋㅋㅋㅋ', '어제보다 나은 내일은 토요일이닼ㅋㅋㅋㅋㅋㅋㅋ', '감탄하고 갔다가 다시 왔습니다. 흡인력 쩌네요.', '2:12 ㅋㅋㅋㅋㅋㅋ', '시드머니 중요', '자막도 넣어주셔서 청각장애인 있는 분들도 보기 편하네영', '와 유현규표저유진짜 킹받네 ㅋㅋㅋㅋ', '5월입니다 스트라이크 그냥두세요 4만넘었네요 네 수고.', '그 일만 많아지고 돈도 그대론데 그걸 누가 할라 그래 "아 내가 하고 있구나" ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '시드머니 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'PD역할 하신분 피부 진짜 좋다', 'ㅋㅋㅋㄱㅋㅋ 재밌군ㅋㅋ', '저사람들 노려보는 눈빛 너무좋아 ㅋㅋㅋ', '너무재밌네 ㅎㅎㅎ 흥하세요🙋🏻\u200d♀️', '고생끝에 골병난다에서 개뿜었네 ㅅㅂㅋㅋㅋㅋㅋㅋㅋ', '태어나서 카풀어플로 벤츠 딱 한번 타봤는데 그 분도 티끌은 모아봐야 티끌이다 편하게 살라했던게 생각나네', 'ㅋㅋㅋㅋ 인터뷰 끝나니까 목소리 겁나 가라앉아ㅋㅋㅋㅋ 대학생도 대학이라는 곳에서 나름대로 살아남기 위해 가면쓰고 과제중이었엉ㅋㅋ 생각해보면 학생도 대학생도 직장인도 쉬운 단계는 없는 것 같아요', '2:13 손가락 디테일 보소 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '현실적으로... 쩝 ㅠ', '진짜 명작이다👏👏👏']

# %%
response = (
  youtube
  .search()
  .list(
    channelId='UCXEKwWflysXu312NmIP_dlw',
    part='snippet',
    maxResults=50
    )
  .execute()
  )
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'aul0x8aQcmNuuQhSC931dJFe1B4',
#  'regionCode': 'KR',
#  'pageInfo': {'totalResults': 36, 'resultsPerPage': 32},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '1OCXrWVjgM5gQ8ZpPN6kPyGEI7g',
#    'id': {'kind': 'youtube#video', 'videoId': 'Xk7wC9zlw_0'},
#    'snippet': {'publishedAt': '2021-10-19T22:29:02Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '이게 나아 이게 나아?',
#     'description': '코믹숏무비 #nerdult #답정너 수정 역 / 한소미 인스타그램 https://www.instagram.com/gksthsl 상협 친구 역 / 유현규 인스타그램 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Xk7wC9zlw_0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Xk7wC9zlw_0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Xk7wC9zlw_0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-10-19T22:29:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'jsZuZ_yEv3A0_GcgDEg9mGyqVho',
#    'id': {'kind': 'youtube#video', 'videoId': 'pdPlgd7rhy4'},
#    'snippet': {'publishedAt': '2021-10-03T07:33:12Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '거기 있는 거 다 안다',
#     'description': '코믹숏무비 #nerdult #누구냐 #거깄는거다안다 경찰&도둑 역 / 유현규 인스타그램 https://www.instagram.com/gyuis_ 집주인 역 / 전 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pdPlgd7rhy4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pdPlgd7rhy4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pdPlgd7rhy4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-10-03T07:33:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '75x-cmNFn_nq2Jh0-Zpx5X70Esg',
#    'id': {'kind': 'youtube#playlist',
#     'playlistId': 'PL2eRTJmFeCBVmTwrqK4-b_bUoc8ps_GUs'},
#    'snippet': {'publishedAt': '2022-06-04T07:35:58Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '너덜트 정주행',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6JOc3ig9w4A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6JOc3ig9w4A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6JOc3ig9w4A/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-06-04T07:35:58Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wXPFkHD9jCgVjkJ8WhaYtMFCEiw',
#    'id': {'kind': 'youtube#video', 'videoId': '6JOc3ig9w4A'},
#    'snippet': {'publishedAt': '2021-07-28T10:33:16Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '너 먹고 싶은 거 먹어',
#     'description': '코믹숏무비 #nerdult #선택장애 #빌런 총잡이 역 / 유현규 인스타그램 https://www.instagram.com/gyuis_ 얌생이 역 / 전상협 인스타 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6JOc3ig9w4A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6JOc3ig9w4A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6JOc3ig9w4A/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-28T10:33:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'lyyxG3FZe5EYR9YXZMEmP7_dFBw',
#    'id': {'kind': 'youtube#video', 'videoId': 'aYbtjGChJjA'},
#    'snippet': {'publishedAt': '2021-09-07T14:49:16Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '강수 확률 50%',
#     'description': '코믹숏무비 #nerdult #오늘의날씨 #기상예보 기상캐스터 역 / 유현규 인스타그램 https://www.instagram.com/gyuis_ 뉴스시청남 역 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/aYbtjGChJjA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/aYbtjGChJjA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/aYbtjGChJjA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-07T14:49:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'KxKWSs64RJGf36NDW33jdZen8To',
#    'id': {'kind': 'youtube#video', 'videoId': 'cINcjVCb5jk'},
#    'snippet': {'publishedAt': '2022-02-18T10:00:20Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '방금 뭐라고 했어?',
#     'description': '코믹숏무비 #nerdult #롤부심 #lol 롤에 빠진 취준생 하하 취준생 역 / 하하 하하PD 유튜브 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cINcjVCb5jk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/cINcjVCb5jk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/cINcjVCb5jk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-18T10:00:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'qIHNKaC6qkvIgXpCj3m6FA0TXbk',
#    'id': {'kind': 'youtube#video', 'videoId': 'KKmvCxsrO4I'},
#    'snippet': {'publishedAt': '2022-02-25T23:10:22Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '무료 PT',
#     'description': '코믹숏무비 #nerdult #헬스장1일차 #피지컬갤러리 무료 PT 해주는 헬창 김계란 관장 역 / 김계란 피지컬갤러리 유튜브 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KKmvCxsrO4I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/KKmvCxsrO4I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/KKmvCxsrO4I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-25T23:10:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Gr5D1WaWhgvu_vtA0se_SQ3N9eE',
#    'id': {'kind': 'youtube#video', 'videoId': 'JPaubSOSxeM'},
#    'snippet': {'publishedAt': '2022-04-23T09:00:07Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '오늘 수정이네 집에서 자고 가려고',
#     'description': '코믹숏무비 #nerdult #외박 부모님 속이고 외박할 때 장소 협찬 : 퍼핀스베이 펜션 경기 가평군 설악면 유명로 2450 전아영 역 / 김아영 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JPaubSOSxeM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JPaubSOSxeM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JPaubSOSxeM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-23T09:00:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'oFgJZh7v6abLOsIteuzQ2iPCjbs',
#    'id': {'kind': 'youtube#video', 'videoId': 'Iy5KojQJjYc'},
#    'snippet': {'publishedAt': '2022-02-11T10:49:54Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '야 부을게',
#     'description': '코믹숏무비 #nerdult #부먹충 #현실남매 찍먹과 부먹, 그것을 두고 벌이는 납치극 스릴러 장소 협찬 : 짬뽕수작 본점 경기 시흥시 함송 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Iy5KojQJjYc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Iy5KojQJjYc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Iy5KojQJjYc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-11T10:49:54Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'z-uitt23hvVme9vHtWjCHZth83c',
#    'id': {'kind': 'youtube#video', 'videoId': 'jxdQh7vs4Ls'},
#    'snippet': {'publishedAt': '2021-08-14T11:43:33Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '당근이세요?',
#     'description': '코믹숏무비 #nerdult #당근마켓남편들 #당근마켓 #중고거래 구매자 역 / 유현규 인스타그램 https://www.instagram.com/gyuis_ ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jxdQh7vs4Ls/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/jxdQh7vs4Ls/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/jxdQh7vs4Ls/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-14T11:43:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '72u3CU6ed2ahC-IJTlIKknETCXI',
#    'id': {'kind': 'youtube#video', 'videoId': 'r4edJvh2I1Q'},
#    'snippet': {'publishedAt': '2022-08-04T04:57:28Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '너희 집 자가였어?',
#     'description': '코믹숏무비 #nerdult #자격지심 실화를 기반으로 한 픽션 자격지심 연출 / 유현규 각본 / 유현규 조연출 / 전상협 임재형 촬영 / 전상협 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/r4edJvh2I1Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/r4edJvh2I1Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/r4edJvh2I1Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-04T04:57:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ihN1BGuZVPlIKU29zYca3wLH808',
#    'id': {'kind': 'youtube#video', 'videoId': 'HMKexUTsHAQ'},
#    'snippet': {'publishedAt': '2022-01-15T19:43:46Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '다 드신 거면 치워드릴게요',
#     'description': '코믹숏무비 #nerdult #불청객 실제 사장님은 너무 친절하시고, 음식도 일품이며 가게는 정상 영업 중입니다 장소 협찬 : 어쩌다 찜한집 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HMKexUTsHAQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HMKexUTsHAQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HMKexUTsHAQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-01-15T19:43:46Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'W21hl-yMgAB6Lk6MYxUgqURWCNQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'XfY-RgyMCvI'},
#    'snippet': {'publishedAt': '2021-12-18T20:11:55Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '지금 가는 중이야',
#     'description': '코믹숏무비 #nerdult #어디야 약속 당일, 막상 나가기 귀찮을 때 장소 협찬 : 준지의 아름다운 하루 서울 마포구 독막로 48, 2층 재형 역 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XfY-RgyMCvI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XfY-RgyMCvI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XfY-RgyMCvI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-18T20:11:55Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'VP3ED0QZhZVUFRpf2Vys72Vdaus',
#    'id': {'kind': 'youtube#video', 'videoId': 'lHfqIwp8MQE'},
#    'snippet': {'publishedAt': '2022-07-04T03:55:16Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '커플 싸움 직관',
#     'description': '코믹숏무비 #nerdult #싸움구경 참을 수 없는 강 건너 불구경 여자친구 역 / 임소윤 인스타그램 https://www.instagram.com/cowyun97 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lHfqIwp8MQE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lHfqIwp8MQE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lHfqIwp8MQE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-04T03:55:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6KiO1o4fvVr7BQSIydEDwU5AX6s',
#    'id': {'kind': 'youtube#video', 'videoId': 'VW7_ug2PkiA'},
#    'snippet': {'publishedAt': '2022-03-29T10:56:35Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '신분증 보여주세요',
#     'description': '코믹숏무비 #nerdult #편의점 미성년자 민증 검사 알바생 역 / 임소윤 인스타그램 https://www.instagram.com/cowyun97 줄 서는 손님 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VW7_ug2PkiA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/VW7_ug2PkiA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/VW7_ug2PkiA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-29T10:56:35Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'YcSbWGsKcMpgYPOdsUaYCzRsrGQ',
#    'id': {'kind': 'youtube#video', 'videoId': '627HBcT1jWY'},
#    'snippet': {'publishedAt': '2022-01-28T02:02:42Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '꿈이요? 퇴산데요',
#     'description': '코믹숏무비 #nerdult #직장인 #퇴사 프로 직장인 인터뷰 장소협찬 (주)퍼비스코리아 직장인 역 / 유현규 인스타그램 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/627HBcT1jWY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/627HBcT1jWY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/627HBcT1jWY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-01-28T02:02:42Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'evszwboqPc-mABxtr2DvQbbCeL4',
#    'id': {'kind': 'youtube#video', 'videoId': 't4IF-TulZxE'},
#    'snippet': {'publishedAt': '2021-12-31T17:38:50Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '최근에 아프거나 한 적 있어요?',
#     'description': '코믹숏무비 #nerdult #신년운세 타로를 하나도 모르는 사람이 운세를 봐주면 생기는 일 누더기 분들 새해 복 많이 받으세요 타로가게 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/t4IF-TulZxE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/t4IF-TulZxE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/t4IF-TulZxE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-31T17:38:50Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'MoaHYrRV78vT_3sIoXjzAv5eOJM',
#    'id': {'kind': 'youtube#video', 'videoId': 'riMHgOa8yf4'},
#    'snippet': {'publishedAt': '2022-06-19T04:24:07Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '군대 어디 나왔다고?',
#     'description': '코믹숏무비 #nerdult #군부심 #군대 한치도 물러서지 않는 군필자들의 자존심 싸움 장소 협찬 : 준지의 아름다운 하루 서울 마포구 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/riMHgOa8yf4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/riMHgOa8yf4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/riMHgOa8yf4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-06-19T04:24:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'D80SB-7-RObPevLnKtEb9Qwe2uw',
#    'id': {'kind': 'youtube#video', 'videoId': 'Yv_-VcPWf9U'},
#    'snippet': {'publishedAt': '2022-03-19T12:55:31Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '밤에 손톱 깎지 말라니까',
#     'description': '코믹숏무비 #nerdult #미신 #문지방 미신에 과도하게 집착하는 친구 미신충 역 / 전상협 인스타그램 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Yv_-VcPWf9U/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Yv_-VcPWf9U/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Yv_-VcPWf9U/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-19T12:55:31Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'im-eAZLpybGKS0POuk_TkarX44I',
#    'id': {'kind': 'youtube#video', 'videoId': 'pKQckMY80u8'},
#    'snippet': {'publishedAt': '2021-11-26T16:23:13Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '필요하신 거 있으시면 말씀해주세요',
#     'description': '코믹숏무비 #nerdult #과잉친절 옷가게 사장과 벌이는 치열한 신경전 장소 협찬 : 베네딕션 강북구 한천로131길 13, 지하 1층 사장 역 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pKQckMY80u8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pKQckMY80u8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pKQckMY80u8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-26T16:23:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mxnVqBoc-hKiswq-N_HF2VFnaqg',
#    'id': {'kind': 'youtube#video', 'videoId': 'ykaSCAp9ysw'},
#    'snippet': {'publishedAt': '2022-07-21T03:00:20Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '고액 과외 면접',
#     'description': '코믹숏무비 #nerdult #자낳괴 은퇴한 조폭 아들과 함께하는 과외 생존기 자낳괴 연출 / 유현규 각본 / 유현규 조연출 / 전상협 임재형 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ykaSCAp9ysw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ykaSCAp9ysw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ykaSCAp9ysw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-21T03:00:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'r_KnCpBtXYYRaqXvr1mNFBOoMsA',
#    'id': {'kind': 'youtube#video', 'videoId': 'yK9bhwuBidA'},
#    'snippet': {'publishedAt': '2022-03-04T09:37:02Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '아니 사진을 이렇게 찍으면',
#     'description': '코믹숏무비 #nerdult #똥손 #인스타그램 사진 못 찍는 남자친구 장소 협찬 : 149 플라밍고 경기 수원시 영통구 법조로149번길 47, 1층 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yK9bhwuBidA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yK9bhwuBidA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yK9bhwuBidA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-04T09:37:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'vD2aG1BN4Vemm8GdSAC9BvPsERg',
#    'id': {'kind': 'youtube#video', 'videoId': '-OzngRU77vc'},
#    'snippet': {'publishedAt': '2022-06-04T03:00:00Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '상남자인 척함',
#     'description': '코믹숏무비 #nerdult #하남자특 #침투부 유행어 전염이 잘못되었을 때 아영 역 / 김아영 인스타그램 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-OzngRU77vc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-OzngRU77vc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-OzngRU77vc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-06-04T03:00:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'of3TWfc6q6g4wRlc1-t4Bsm1lzo',
#    'id': {'kind': 'youtube#video', 'videoId': '03HKx-YTnxs'},
#    'snippet': {'publishedAt': '2022-03-12T15:24:00Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '카페 전기 도둑',
#     'description': '코믹숏무비 #nerdult #카공족 #앱등이 하루 종일 카페에서 공부하는 앱등이 장소 협찬 : 89헤르츠 카페 서울특별시 영등포구 영신로9 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/03HKx-YTnxs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/03HKx-YTnxs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/03HKx-YTnxs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-12T15:24:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ilx2NOkaTn_64LVzKLWrXpnQ_YI',
#    'id': {'kind': 'youtube#video', 'videoId': '5rjiSkFuKOI'},
#    'snippet': {'publishedAt': '2022-05-08T03:00:01Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '한국은 안 훔쳐가',
#     'description': '코믹숏무비 #nerdult #문화차이 #자리싸움 외국인 친구가 한국에 와서 놀라는 것 장소 협찬 : 네이밍카페 커피GO 서울 관악구 봉천로 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5rjiSkFuKOI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5rjiSkFuKOI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5rjiSkFuKOI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-05-08T03:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'iqFbJsaBpnEVkSswxcJbxMXKeSk',
#    'id': {'kind': 'youtube#video', 'videoId': 'YiQt3IANmzc'},
#    'snippet': {'publishedAt': '2022-04-03T04:00:16Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '아까부터 계속 야리네',
#     'description': '코믹숏무비 #nerdult #기싸움 #허세 술집에서 눈 마주치면 벌어지는 일 장소 협찬 : 인쌩맥주 잠실신천점 서울 송파구 백제고분로7길 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/YiQt3IANmzc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/YiQt3IANmzc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/YiQt3IANmzc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-03T04:00:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'MO1Mbt5QDsJq6Mg8-K7s2YuRz48',
#    'id': {'kind': 'youtube#video', 'videoId': 'Jdvv5YNFEZ8'},
#    'snippet': {'publishedAt': '2022-05-22T03:00:10Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '에헤이 먼저 타라니까',
#     'description': '코믹숏무비 #nerdult #이타적인사람들 배려심이 남다른 사람끼리 만났을 때 장소 협찬 : 우돈명가 경기 광명시 도덕공원로 54(철산동 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Jdvv5YNFEZ8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Jdvv5YNFEZ8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Jdvv5YNFEZ8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-05-22T03:00:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'JibPsAOli155JAzm50cY3UVoHrs',
#    'id': {'kind': 'youtube#video', 'videoId': 'BDVKdvmY7OU'},
#    'snippet': {'publishedAt': '2022-04-13T10:00:04Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '너 그거 INFP라 그래',
#     'description': '코믹숏무비 #nerdult #MBTI #취업 MBTI 과몰입한 친구 임 대리 역 / 임소윤 인스타그램 https://www.instagram.com/cowyun97 뜨거운 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BDVKdvmY7OU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BDVKdvmY7OU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BDVKdvmY7OU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-13T10:00:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'bXsIBhYYoqXAco5iLsyIzmmhddQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'zCcaAQjlgsg'},
#    'snippet': {'publishedAt': '2021-09-21T14:48:13Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '전화 울렁증',
#     'description': '코믹숏무비 #nerdult #그놈목소리 #전화공포증 #콜포비아 장소 협찬 : 자담치킨 상도1점 친구1 역 / 유현규 인스타그램 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zCcaAQjlgsg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zCcaAQjlgsg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zCcaAQjlgsg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-21T14:48:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '3nMUtHUXrLvwNBQ8azqNG35_kmA',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UCXEKwWflysXu312NmIP_dlw'},
#    'snippet': {'publishedAt': '2021-06-21T08:55:19Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '너덜트',
#     'description': '문의는 메일로 부탁드립니다 :) nerdult1@gmail.com.',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/q-uQmCdiiOFQsHU83mfWqS3rpdRJXRW9zb_vpyr2MtInkqsVtQwc3ej3rouyVORHL6Dvx7--Iw=s88-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/q-uQmCdiiOFQsHU83mfWqS3rpdRJXRW9zb_vpyr2MtInkqsVtQwc3ej3rouyVORHL6Dvx7--Iw=s240-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/q-uQmCdiiOFQsHU83mfWqS3rpdRJXRW9zb_vpyr2MtInkqsVtQwc3ej3rouyVORHL6Dvx7--Iw=s800-c-k-c0xffffffff-no-rj-mo'}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-06-21T08:55:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'b5lJ7vWhaXneYGw723obon0MPaU',
#    'id': {'kind': 'youtube#video', 'videoId': 'rlEa--Lh6OY'},
#    'snippet': {'publishedAt': '2021-11-13T12:00:11Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '괴물 신인 너덜트의 모든 것',
#     'description': '코믹숏무비 #nerdult #큐앤에이 업로드가 늦어 죄송합니다 너덜트 감독 / 유현규 인스타그램 https://www.instagram.com/gyuis_ 너덜 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rlEa--Lh6OY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/rlEa--Lh6OY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/rlEa--Lh6OY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-13T12:00:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'tCLPdgjS_NylMexyUw7OLFUGUy4',
#    'id': {'kind': 'youtube#video', 'videoId': '7bs9-VU8uHI'},
#    'snippet': {'publishedAt': '2022-08-27T06:45:28Z',
#     'channelId': 'UCXEKwWflysXu312NmIP_dlw',
#     'title': '커피 좀 타 드릴까요?',
#     'description': '코믹미들무비 #nerdult #소심한복수 복수를 꿈꾸는 신입 사원의 고군분투 신입사원 역 / 전상협 인스타그램 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7bs9-VU8uHI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7bs9-VU8uHI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7bs9-VU8uHI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '너덜트',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-27T06:45:28Z'}}]}

# %%
list1 = []
channelid=''
def youtube_channel_title(list1, channelid):
  response = (
    youtube
    .search()
    .list(
      channelId='UCXEKwWflysXu312NmIP_dlw',
      part='snippet',
      maxResults=50
      )
      .execute()
      )
  while response.

# %% [markdown]
# # Dart

# %% [markdown]
# 특정 정보 추출하기

# %%
import pandas as pd
import requests
from tqdm import tqdm
from bs4 import BeautifulSoup
import xmltodict
import json
import time

# %%
api_key = '03880acf9b9a1701f822dbbe25c4340eaaddfe57'

# %%
dart_information_url = f'https://opendart.fss.or.kr/api/list.json?crtfc_key={api_key}&bgn_de=20200117&end_de=20200117&corp_cls=Y&page_no=1&page_count=10'

# %%
# dart_information_source = requests.get(dart_information_url)
# eval(dart_information_source.text)

# %%
# for name in tree.getroot().iter('list'):
#     print(list(name))

# %%
import requests
import io
import zipfile
import xmltodict
import pandas as pd
from tqdm import tqdm

# %%
key = "03880acf9b9a1701f822dbbe25c4340eaaddfe57"
url = "https://opendart.fss.or.kr/api/corpCode.xml"

params = {
    "crtfc_key": key
}
resp = requests.get(url, params=params)

# %%
f = io.BytesIO(resp.content)
zfile = zipfile.ZipFile(f)
zfile.namelist()
xml = zfile.read("CORPCODE.xml").decode("utf-8")
dict_data = xmltodict.parse(xml)
code_lists = dict_data.get('result').get('list')
list1 = []
for code_list in code_lists:
    list1.append(code_list.get('corp_code'))

# %%
api_key = 'aad8902f062d010bc147854f95f914ff684f3092'

# %%
corp_20_list = ['00126380','01515323', '00164779', '00877059', '00356361', '00164742', '00126362', '00266961', '00106641', '00258801', '00413046', '00149655', '00155319', '00164788', '00688996', '00382199', '00631518', '00181712', '00401731', '00126256']

# %% [markdown]
# ## 기업 현황 함수 만들기

# %%
def industry_economics(corp_code):
    api_key = 'aad8902f062d010bc147854f95f914ff684f3092'
    url = f'https://opendart.fss.or.kr/api/company.json?crtfc_key={api_key}&corp_code={corp_code}'
    response = requests.get(url)
    return eval(response.text)

# %%
pd.DataFrame(industry_economics('00432403'), index=['기업'])
# Out:
#    status message corp_code corp_name          corp_name_eng stock_name  \
# 기업    000      정상  00432403   한라판지(주)  HANLA PARKING CO.,LTD       한라판지
#
#    stock_code ceo_nm corp_cls       jurir_no     bizr_no  \
# 기업               정우석        E  2201110019993  6168120149
#
#                        adres hm_url ir_url        phn_no        fax_no  \
# 기업  제주특별자치도 북제주군 한림읍 상명리 587                064-796-8001  064-796-8003
#
#    induty_code    est_dt acc_mt
# 기업       17123  19970601     12

# %%
for corp in tqdm(list1[0:5]):
    corp_data = pd.DataFrame(industry_economics(corp),index=['기업'])
    corp_data.to_csv('middle_eilbo.csv', index=False, encoding="utf-8-sig")
# Out:
# 100%|██████████| 5/5 [00:00<00:00,  6.23it/s]

# %%
status = []
message = []
corp_name = []
corp_name_eng = []
stock_name = []
stock_code = []
ceo_nm = []
corp_cls = []
jurir_no = []
bizr_no = []
adres = []
hm_url = []
ir_url = []
phn_no = []
fax_no = []
induty_code = []
est_dt = []
acc_mt = []
for corp in tqdm(corp_20_list):
    status.append(industry_economics(corp).get('status'))
    message.append(industry_economics(corp).get('message'))
    corp_name.append(industry_economics(corp).get('corp_name'))
    corp_name_eng.append(industry_economics(corp).get('corp_name_eng'))
    stock_name.append(industry_economics(corp).get('stock_name'))
    stock_code.append(industry_economics(corp).get('stock_code'))
    ceo_nm.append(industry_economics(corp).get('ceo_nm'))
    corp_cls.append(industry_economics(corp).get('corp_cls'))
    jurir_no.append(industry_economics(corp).get('jurir_no'))
    bizr_no.append(industry_economics(corp).get('bizr_no'))
    adres.append(industry_economics(corp).get('adres'))
    hm_url.append(industry_economics(corp).get('hm_url'))
    ir_url.append(industry_economics(corp).get('ir_url'))
    phn_no.append(industry_economics(corp).get('phn_no'))
    fax_no.append(industry_economics(corp).get('fax_no'))
    induty_code.append(industry_economics(corp).get('induty_code'))
    est_dt.append(industry_economics(corp).get('est_dt'))
    acc_mt.append(industry_economics(corp).get('acc_mt'))
corp_20_data = pd.DataFrame({'status': status,
'message': message,
'corp_name': corp_name,
'corp_name_eng': corp_name_eng,
'stock_name': stock_name,
'stock_code': stock_code,
'ceo_nm': ceo_nm,
'corp_cls': corp_cls,
'jurir_no': jurir_no,
'bizr_no': bizr_no,
'adres': adres,
'hm_url': hm_url,
'ir_url': ir_url,
'phn_no': phn_no,
'fax_no': fax_no,
'induty_code': induty_code,
'est_dt': est_dt,
'acc_mt': acc_mt})

# %%
corp_20_data.to_csv('기업개황.csv', index=False, encoding="utf-8-sig")

# %% [markdown]
# ## 재무 제표 함수 만들기

# %%
corp_code = ''
def dart_economy(corp_code):
    api_key = 'aad8902f062d010bc147854f95f914ff684f3092'
    search_url = f'https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json?crtfc_key={api_key}&corp_code={corp_code}&bsns_year=2021&reprt_code=11011&fs_div=CFS'
    search_response = requests.get(search_url)
    search_json = eval(search_response.text)
    if search_json.get('list') == None:
        return []
    else:
        return eval(search_response.text).get('list')

# %%
rcept_no = []
reprt_code = []
bsns_year = []
sj_div = []
sj_nm = []
account_id = []
account_nm = []
account_detail = []
thstrm_nm = []
thstrm_amount = []
ord = []
currency = []
for number in tqdm(corp_20_list):
    for i in dart_economy(number):
        rcept_no.append(i.get('rcept_no'))
        reprt_code.append(i.get('reprt_code'))
        bsns_year.append(i.get('bsns_year'))
        sj_div.append(i.get('sj_div'))
        account_id.append(i.get('account_id'))
        account_nm.append(i.get('account_nm'))
        account_detail.append(i.get('account_detail'))
        thstrm_nm.append(i.get('thstrm_nm'))
        thstrm_amount.append(i.get('thstrm_amount'))
        ord.append(i.get('ord'))
        currency.append(i.get('currency'))
dart_20_economy_data = pd.DataFrame({
    'rcept_no' : rcept_no,
    'reprt_code' : reprt_code,
    'bsns_year' : bsns_year,
    'sj_div' : sj_div,
    'account_id' : account_id,
    'account_nm' : account_nm,
    'account_detail' : account_detail,
    'thstrm_nm' : thstrm_nm,
    'thstrm_amount' : thstrm_amount,
    'ord' : ord,
    'currency' : currency
    })

# %%
dart_20_economy_data.to_csv('재무제표.csv', index=False, encoding="utf-8-sig")
