# %% [markdown]
# ## 3.3 조건문
#
# 반복문은 어떤 수행 작업을 한 번이 아니라 계속해서 수행해야 할 때 사용.
# 반복문은 while과 for 두 가지 존재.

# %% [markdown]
# ### 3.3.1 for
#
# for문은 값의 범위나 횟수가 정해져 있을 때 사용.
# while문에 비해서 자주 사용되는 반복문.
#
# > * for문 기본 구조
# for 변수 in 반복가능객체:
# &nbsp;&nbsp;&nbsp;&nbsp;반복실행문
#
# for문은 조건식이 존재하지 않고 '변수'와 '반복가능객체'만 사용하고 있음.
#
# **반복가능객체**
# 여러 개의 데이터를 저장하고 있는 객체를 '반복가능객체'라고 부름
# for문에서 사용되는 반복가능한 주요 객체는 다음과 같음
#
# |구분|자료형|예제|
# |-|-|-|
# |sequence|문자열|'hello'|
# ||리스트|[1, 2, 3]|
# ||튜플|(1, 2, 3)|
# ||range|range(100)|
# |non-sequence|set|{1, 2, 3}|
# ||tuple|{'a': 'apple', 'b': 'banana'}|
#
# <br>
#
# **List Comprehension**
# > 사용법
#   [표현식 for 변수 in 반복가능객체]

# %%
for x in range(2, 10):
    for y in range(1, 10):
        print(f'{x} X {y} = {x * y} 입니다.')
    print()
# Out:
# 2 X 1 = 2 입니다.
# 2 X 2 = 4 입니다.
# 2 X 3 = 6 입니다.
# 2 X 4 = 8 입니다.
# 2 X 5 = 10 입니다.
# 2 X 6 = 12 입니다.
# 2 X 7 = 14 입니다.
# 2 X 8 = 16 입니다.
# 2 X 9 = 18 입니다.
#
# 3 X 1 = 3 입니다.
# 3 X 2 = 6 입니다.
# 3 X 3 = 9 입니다.
# 3 X 4 = 12 입니다.
# 3 X 5 = 15 입니다.
# 3 X 6 = 18 입니다.
# 3 X 7 = 21 입니다.
# 3 X 8 = 24 입니다.
# 3 X 9 = 27 입니다.
#
# 4 X 1 = 4 입니다.
# 4 X 2 = 8 입니다.
# 4 X 3 = 12 입니다.
# 4 X 4 = 16 입니다.
# 4 X 5 = 20 입니다.
# 4 X 6 = 24 입니다.
# 4 X 7 = 28 입니다.
# 4 X 8 = 32 입니다.
# 4 X 9 = 36 입니다.
#
# 5 X 1 = 5 입니다.
# 5 X 2 = 10 입니다.
# 5 X 3 = 15 입니다.
# 5 X 4 = 20 입니다.
# 5 X 5 = 25 입니다.
# 5 X 6 = 30 입니다.
# 5 X 7 = 35 입니다.
# 5 X 8 = 40 입니다.
# 5 X 9 = 45 입니다.
#
# 6 X 1 = 6 입니다.
# 6 X 2 = 12 입니다.
# 6 X 3 = 18 입니다.
# 6 X 4 = 24 입니다.
# 6 X 5 = 30 입니다.
# 6 X 6 = 36 입니다.
# 6 X 7 = 42 입니다.
# 6 X 8 = 48 입니다.
# 6 X 9 = 54 입니다.
#
# 7 X 1 = 7 입니다.
# 7 X 2 = 14 입니다.
# 7 X 3 = 21 입니다.
# 7 X 4 = 28 입니다.
# 7 X 5 = 35 입니다.
# 7 X 6 = 42 입니다.
# 7 X 7 = 49 입니다.
# 7 X 8 = 56 입니다.
# 7 X 9 = 63 입니다.
#
# 8 X 1 = 8 입니다.
# 8 X 2 = 16 입니다.
# 8 X 3 = 24 입니다.
# 8 X 4 = 32 입니다.
# 8 X 5 = 40 입니다.
# 8 X 6 = 48 입니다.
# 8 X 7 = 56 입니다.
# 8 X 8 = 64 입니다.
# 8 X 9 = 72 입니다.
#
# 9 X 1 = 9 입니다.
# 9 X 2 = 18 입니다.
# 9 X 3 = 27 입니다.
# 9 X 4 = 36 입니다.
# 9 X 5 = 45 입니다.
# 9 X 6 = 54 입니다.
# 9 X 7 = 63 입니다.
# 9 X 8 = 72 입니다.
# 9 X 9 = 81 입니다.

# %%
a = [1, 2, 3, 4, 5, 6]
b = []
for number in a:
    if number % 2 == 0:
        b.append(number)
print(b)
# Out:
# [2, 4, 6]

# %%
[number for number in a if number % 2 == 0]
# Out:
# [2, 4, 6]

# %%
[number + 1 for number in a]
# Out:
# [2, 3, 4, 5, 6, 7]

# %% [markdown]
# ### 3.3.2 while
#
# 1.   while
# while문은 특정 조건을 만족하는 동안 반복해서 수행해야 하는 코드를 작성할 때 사용.
#
# > * while문의 기본 구조는 다음와 같음
# while 조건식:
#      &nbsp;&nbsp;&nbsp;&nbsp;반복실행문.
#      <br>
#      <br>
#      조건식의 결과가 True이면 while문을 실행
#      <br>
#      반복문 실행이 종료되면 다시 조건식으로 이동
#      <br>
#      조건식의 결과가 False이면 더 이상 반복 실행문을 실행하지 않음
# <br>
#
# 2.   while문이 필요한 경우
# while문은 주로 횟수가 정해지지 않은 연산을 진행할 때나
# 어떤 특정 동작이 지속될 때 사용
# <br>
#
#
# 3.   while문의 중첩
# while문 내부에 또 다른 while문이 나타나는 것을 while문의 중첩이라고 함
# <br>
# 반복처리해야 하는 대상이 2개 이상이면 while문의 중첩이 필요.

# %%
a = [1, 2, 3, 4, 5]
while a:
    print(a.pop())
    print(a)
print("끝")
# Out:
# 5
# [1, 2, 3, 4]
# 4
# [1, 2, 3]
# 3
# [1, 2]
# 2
# [1]
# 1
# []
# 끝

# %%
a = []
while len(a) < 5:
    a.append(input())
    print(a)
# Out:
# ['3']
# ['3', '4']
# ['3', '4', '5']
# ['3', '4', '5', '7']
# ['3', '4', '5', '7', '7']
# ['3', '4', '5', '7', '7', '1']

# %%
while True:
    number_1 = int(input("번호를 입력하세요. "))
    if number_1 == 486:
        print("사랑해")
        break
    else:
        print("틀렸습니다. 다시 입력하십시오.")

# %% [markdown]
# ## 3.4 사용자 정의 함수
#
# * 사용자 함수란 사용자가 직접 만든 함수
# * 내장 함수는 이미 만들어져 있어 사용법대로 사용하면 되지만,
# 모든 일을 내장 함수를 이용하여 처리 불가능
# <br>
# <br>
#
# 사용자 함수를 구현하기 위해 다음의 용어 정리 필요
# * 함수 정의(define): 사용자 함수를  새로 만드는 것
# * 인수(argument): 사용자 함수에 전달할 입력
# * 매개변수(parameter): 인수를 받아서 저장하는 변수
# * 반환값(return): 사용자 함수의 출력
# * 함수 호출(call): 만들어진 사용자 함수를 실제로 사용
#
# <br>
# <br>
#
# 기본적 함수 정의는 다음과 같음
# def 함수 이름(매개변수):
# &nbsp;&nbsp;&nbsp;&nbsp;본문
# &nbsp;&nbsp;&nbsp;&nbsp;return 반환값
# <br>
# <br>
#
# **가변 매개변수**
# 함수로 전달해야 하는 인수의 개수가 정해지지 않아도
# 매개변수 선언 가능한데 이를 가변 매개변수라고 함
#
# 가변 매개변수를 만드는 키워드는 애스터리스크(*)이며 개수에 따른 차이가 있음
#
# 1. def show(*args):
# &nbsp;&nbsp;&nbsp;&nbsp;for item in args:
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;print(item)
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;show('happy', 'birthday')
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;-> 인자를 튜플로 전달
#
# 2. def show(**kwargs):
# &nbsp;&nbsp;&nbsp;&nbsp;for key, item in args:
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;print(key, item)
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;show(a=1, b=2)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;-> 인자를 딕셔너리로 전달

# %%
def add1(number):
    new_number = number + 1

    return new_number

add1(5)
# Out:
# 6

# %%
def add1(number, default = 2):
    new_number =number + 1
    return new_number
add1(5)
# Out:
# 6

# %%
def add2(number, condition = True):
    if condition:
        return number + 1
    else:
        return number

print(add2(5))
print(add2(5, condition = False))
# Out:
# 6
# 5

# %%
def add3(*args, condition=True):
    print(args)
    if condition:
        return sum(args) + 1
    else:
        return sum(args)

print(add3(1, 2, 3, 4, 5, condition=True))
print(add3(1, 2, 3, 4, condition=False))
# Out:
# (1, 2, 3, 4, 5)
# 16
# (1, 2, 3, 4)
# 10

# %%
def practice(**kwargs):
    print(kwargs)

print(practice(a=1, b=2, c=3))
print(practice(d=4, e=5))
# Out:
# {'a': 1, 'b': 2, 'c': 3}
# None
# {'d': 4, 'e': 5}
# None

# %% [markdown]
# ## 3.5 클래스

# %% [markdown]
# ### 3.5.1 클래스 정의 및 생성
#
# 클래스(class)를 한 마디로 정의하면 객체를 만드는 도구.
# 하나의 클래스를 만들어 두면 그 클래스를 통해 여러 개의 객체를 만들 수 있음.
#
# 흔히 얘기하는 붕어빵 틀과 붕어빵 예를 들어 붕어빵 틀이 있으면
# 틀을 활용해 여러 개의 붕어빵을 만들 수 있음.
#
# <br>
#
# 같은 붕어빵 틀로 만든 붕어빵이라도 서로 다른 모양과 크기를 가진 붕어빵을 만들 수 있음
# 클래스와 객체도 마찬가지로 같은 클래스로 만든 객체라도 객체들은 서로 다른 값을 가질 수 있음.
#
# <br>
#
# 인스턴스(instance)는 클래스를 이용해 생성한 객체를 가리키는 용어.
# 객체와 인스턴스는 그 둘을 바라보는 관점의 차이.
#
# 붕어빵 클래스로 만든 붕어빵은 객체(obejct),
# 붕어빵은 붕어빵 클래스의 인스턴스(instance)
#
# <br>
# <br>
#
# **클래스 정의**
#
# 클래스를 작성하는 것을 클래스 정의라고 함.
# 클래스 정의 방법은 다음과 같음.
#
# class 키워드로 클래스 정의.
# 파이썬 클래스 이름은 Cap Words(Upper Camel Case) 규칙을 따름(PEP8).
#
# ```python
# class 클래스:
#   본문
# ```
#
# <br>
# <br>
#
# **객체 생성**
# 클래스가 정의되면 다음과 같은 형식으로 객체 생성 가능.
#
# ```python
# 객체 = 클래스()
# ```
#
# 2개의 객체를 만들고 싶으면 다음과 같이 작업
# ```python
# 객체1 = 클래스()
# 객체2 = 클래스()
# ```
# <br>
#
# 실제 클래스와 객체를 다음과 같이 만들 수 있음
#
# ```python
# class FishShapedBun:
#   pass
#
# fish_shaped_bun = FishShapedBun()
# ```

# %% [markdown]
# ### 3.5.2 클래스의 구성
#
# 객체를 생성하기 위해서 클래스는 객체가 가져야 할 값과 기능을 가지고 있어야 함.
#
# 사람을 예로 들면 다음과 같은 기능을 가지고 있음.
#
# ```python
# 값: 이름, 나이, 연락처, 주소 등
# 기능: 잔다, 먹는다, 공부한다, 달린다 등
# ```
# 사람(객체)가 가지고 있는 값은 변수, 사람이 할 수 있는 기능은 함수라고 볼 수 있음.
#
# 클래스를 구성하는 변수는 2가지로 분리 가능.
# *  클래스 변수: 클래스를 기반으로 생성된 모든 인스턴스들이 공유하는 변수.
# *  인스턴스 변수: 모든 인스턴스들이 개별적으로 가지는 변수인 인스턴스 변수.
#
# 클래스를 구성하는 함수는 더 이상 함수라고 부르지 않음.
# 클래스 내부에 존재하는 함수는 메소드라고 함.
# 메소드는 특징에 따라 클래스 메소드, 정적 메소드, 인스턴스 메소드로 분리 가능.
#
# <br>
# <br>
#
#
# **인스턴스 변수와 인스턴스 메소드**
#
# * 인스턴스 변수: 클래스 기반으로 만들어지는 모든 인스턴스들이 각각 따로 저장하는 변수.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;모든 인스턴스 변수는 self라는 키워드를 앞에 붙여줌.
# * 인스턴스 메소드: 인스턴스 변수를 사용하는 메소드.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;인스턴스 변수값에 따라 각 인스턴스마다 다르게 동작.
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;인스턴스 메소드는 반드시 첫 번째 매개변수로 self를 추가.
#
# <br>
# <br>
#
# **생성자**
# 생성자는 인스턴스를 생성할 때 자동으로 호출되는 특별한 메소드.

# %%
students = [
    {"name" : "한주상", "korean" : 40, "math" : 100, "english" : 80, "science" : 100},
    {"name" : "한선우", "korean" : 60, "math" : 50, "english" : 78, "science" : 60},
    {"name" : "김영민", "korean" : 87, "math" : 45, "english" : 68, "science" : 55},
    {"name" : "최연수", "korean" : 80, "math" : 100, "english" : 55, "science" : 95},
    {"name" : "배정우", "korean" : 90, "math" : 75, "english" : 95, "science" : 100},
    {"name" : "최진영", "korean" : 85, "math" : 95, "english" : 80, "science" : 65}
]

print("이름", "총점", "평균", sep="\t")

for student in students:
    score_sum = student["korean"] + student["math"] + student["english"] + student["science"]
    score_average = score_sum / 4
    print(student["name"], score_sum, score_average, sep="\t")
# Out:
# 이름	총점	평균
# 한주상	320	80.0
# 한선우	248	62.0
# 김영민	255	63.75
# 최연수	330	82.5
# 배정우	360	90.0
# 최진영	325	81.25

# %%
class Student():
    def __init__(self, name, math, korean, english, science):
        self.name = name
        self.math = math
        self.korean = korean
        self.english = english
        self.science = science

students= [
    Student("윤인성", 87, 98, 88, 95),
    Student("연하진", 92, 98, 96, 98),
    Student("구지연", 76, 96, 94, 98),
    Student("나선주", 98, 92, 96, 92),
    Student("윤아린", 95, 98, 98, 98),
    Student("윤명월", 64, 88, 92, 92)
]
for student in students:
    print(student.name + "\t" + str(student.math) + "\t" + str(student.korean) + "\t" + str(student.english) + "\t" + str(student.science))
# Out:
# 윤인성	87	98	88	95
# 연하진	92	98	96	98
# 구지연	76	96	94	98
# 나선주	98	92	96	92
# 윤아린	95	98	98	98
# 윤명월	64	88	92	92

# %% [markdown]
# ### 3.5.3 클래스 메소드와 정적 메소드
#
# **클래스 변수**
# 클래스를 구현할 때 인스턴스마다 서로 다른 값을 가지는 경우에 인스턴스 변수 사용.
# 사람을 클래스로 구현한다고 가정하면 사람들의 이름, 나이 주소 등과 같이
# 사람마다 다른 값을 가지는 것들을 인스턴스 변수로 저장.
# 이때, 모든 인스턴스 변수들은 self 키워드를 붙여 사용.
# <br>
# 이번에는 인스턴스들이 서로 같은 값을 가지는 경우를 가정.
# 한국 사람들을 클래스로 구현한다고 가정하면,
# 사람들의 이름, 나이, 주소 등은 여전히 인스턴스마다
# 서로 다른 값을 가지겠지만, 소속 국가는 그렇지 않음.
# 한국 사람 클래스로 만든 모든 인스턴스의 소속 국가는 바로 한국.
# 이렇게 모든 인스턴스가 동일한 값을 사용할 때,
# 이를 클래스 변수로 처리해 모든 인스턴스들이 공유하도록 처리.
# <br>
# 인스턴스 변수는 인스턴스마다 값을 별도로 저장해야 하지만
# 클래스 변수는 하나의 값을 모든 인스턴스가 공유하기 때문에
# 메모리 공간의 낭비를 막을 수 있음.
#
# <br>
# <br>
#
# **클래스 메소드**
#
# 클래스 메소드란 클래스 변수를 사용하는 메소드.
# 다음과 같은 특징을 가짐.
#
# 1. 인스턴스 또는 클래스로 호출
# 2. 생성된 인스턴스가 없어도 호출
# 3. @classmethod 데코레이터(decorator)를 표시하고 작성
# 4. 매개변수 self를 사용하지 않고 cls를 사용
#
# 클래스 메소드는 인스턴스를 통해 호출하지 않고 클래스.메소드()와 같은 형식으로 호출.
# 클래스 메소드는 self를 사용하지 않기에 인스턴스 변수에 접근할 수 없지만,
# cls를 통해 클래스 변수에는 접근 가능.
#
# <br>
# <br>
#
# **정적 메소드**
#
# 정적 메소드 역시 self를 사용하지 않기 때문에 인스턴스 변수 사용 불가.
# 인스턴스를 생성하지 않아도 사용할 수 있는 메소드라는 점에서 클래스 메소드와 비슷.
# 정적 메소드의 주요 특징은 다음과 같음.
#
# 1. 인스턴스 또는 클래스로 호출
# 2. 생성된 인스턴스가 없어도 호출 가능
# 3. @staticmethod 데코레이터를 표시하고 작성
# 4. 반드시 작성해야 할 매개변수가 없음
#
# 정적 메소드는 self와 cls 모두 사용하지 않기 때문에
# 인스턴스 변수와 클래스 변수 모두 사용하지 않는 메소드를 정의하는 경우에 적절.
# 정적 메소드는 클래스에 소속되어 있지만,
# 인스턴스에는 영향을 주지 않고 또 인스턴스로부터 영향을 받지도 않음.

# %%
class mathformula:
    def __init__(self, num1,  num2):
        self.num1 = num1
        self.num2 = num2
    
    def add(self):
        return self.num1 + self.num2
    
    def subtract(self):
        return self.num1 - self.num2

    def multiply(self):
        return self.num1 * self.num2
    
    def divide(self):
        return self.num1 / self.num2


a = mathformula(2, 3)
print(a.add())
print(a.subtract())
print(a.multiply())
print(a.divide())
# Out:
# 5
# -1
# 6
# 0.6666666666666666

# %%
class Student:
    count = 0
    students = []
    @classmethod
    def print(cls):
        print("------ 학생 목록 ------")
        print("이름\t학점\t평균")
        for student in cls.students:
            print(str(student))
        print("------ ------- ------")

    
    def __init__(self, name, korean, math, english, science):
        self.name = name
        self.korean = korean
        self.math = math
        self.english = english
        self.science = science
        Student.count += 1
        Student.students.append(self)

    def get_sum(self):
        return self.korean + self.math + self.english + self.science
    
    def get_average(self):
        return self.get_sum / 4

    def __str__(self):
        return "{}\t{}\t{}".format(self.name, self.get_sum(), self.get_average())

# %% [markdown]
# ### 3.5.4 상속
#
# 파이썬에서는 어떤 클래스가 가지고 있는 기능을 그대로 물려받아 사용할 수 있는 클래스를 만들 수 있음.
# 다른 클래스의 기능을 물려받을 때 상속받는다는 표현 사용.
# 그래서 상속 관계에 있는 클래스를 표현할 때 부모, 자식클래스라는 단어 사용.
#
# 아래는 상속 관계 클래스를 나타내는 용어
#
# |구분|부모 클래스|자식 클래스|
# |----- |-----------------------------------------------------|---------------------|
# |의미  |상속해주는 클래스                                    |상속받는 클래스       |
# |용어  |슈퍼 클래스(super class) <br><br> 기반 클래스(base class)   |서브 클래스(sub class) <br><br> 파생 클래스(derived class)|
#
# 파이썬에선 super라는 키워드는 부모 클래스를 지정하는 용도로 사용.
#
# <br>
# <br>
#
# **상속 관계 구현**
#
# 기본적으로 두 클래스가 상속 관계에 놓이려면 IS-A 관계가 성립.
# IS-A 관계란 '~은 ~이다.'로 해석될 수 있는 관계.
# 예를 들면 '학생은 사람이다'.처럼 해석되는 관계가 IS-A 관계.
# <br>
# '학생은 사람이다'를 'Student is a Person'으로 해석 가능.
# 이때, Student는 자식 클래스가 되고, Person은 슈퍼 클래스.
# 슈퍼 클래스는 일반 클래스처럼 구현하면 되지만,
# 서브 클래스는 어떤 슈퍼 클래스를 상속받는지 명시할 수 있도록 새로운 문법 사용.
#
# 상속의 기본적인 형식은 다음과 같음.
# ```python
# class 부모 클래스:
#   본문
#
# class 자식 클래스(슈퍼 클래스):
#   본문
# ```
# 자식 클래스 구현 시 괄호 안에 어떤 부모 클래스를 상속받는지 명시.
# 상속 관계에 놓은 서브 클래스는 마치 자신의 것처럼 슈퍼 클래스 기능 사용 가능.
#
# <br>
# <br>
#
# **자식 클래스의 \_\_init\_\_()**
#
# 자식 클래스는 부모 클래스가 없으면 존재할 수 없음.
# 부모가 존재해야 자식도 존재.
# 따라서 자식 클래스의 생성자 구현 시
# 반드시 부모 클래스의 생성자를 호출하는 코드를 작성해야만 함.
#
# Student 클래스의 생성자인 \_\_init\_\_() 메소드의 예시
# ```python
# def __init__(self, name, school):
#   super().__init__(name)
#   self.school = school
# ```
#
# super라는 키워드는 부모 클래스 의미.
# Student를 생성하기 위해 Student의 생성자를 호출하면
# super().\_\_init\_\_(name)에 의해 부모 클래스인 Person의 생성자가 먼저 호출되면서 부모 클래스 생성.
# 부모 클래스의 Person 생성에는 name이 필요하므로 name이 함께 전달.
# 이 과정으로 부모 클래스 Person의 생성이 끝나면
# 이제 자식 클래스 Student도 school의 값을 저장하며 생성.

# %%
class Parent:
    def __init__(self):
        self.value = "테스트"
        print("Parent 클래스의 __init__()의 메소드입니다.")
    def test(self):
        print("Parent 클래스의 test()입니다.")

class Child(Parent):
    def __init__(self):
        Parent.__init__(self)
        print("Child 클래스의 __init()__의 메소드가 호출되었습니다.")

child = Child()
print(child.test)
print(child.value)
# Out:
# Parent 클래스의 __init__()의 메소드가 호출되었습니다.
# Child 클래스의 __init()__의 메소드가 호출되었습니다.
# <bound method Parent.test of <__main__.Child object at 0x0000027F586DE760>>
# 테스트

# %% [markdown]
# ### 3.5.5 오버라이딩
#
# 부모 클래스에서 이미 정의된 메소드를 자식 클래스에서 다시 정의하는 것.
# 상속 후 메소드를 호출하게 되면 자식 클래스에서 다시 정의된 메소드를 사용.
# 이 경우, 부모 클래스에서 정의된 메소드는 사용 불가.

# %%
class CustomException(Exception):
    def __init__(self):
        Exception.__init__(self)
        print("##### 내가 만든 오류가 생성되었어요! #####")
    def __str__(self):
        return "코드 발편 불가"

raise CustomException
# Out:
# ##### 내가 만든 오류가 생성되었어요! #####
# ---------------------------------------------------------------------------
# CustomException                           Traceback (most recent call last)
# c:\bigdata_git\bigdata_thunder\bigdata1\day02.ipynb 셀 32 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/day02.ipynb#X44sZmlsZQ%3D%3D?line=4'>5</a>     def __str__(self):
#       <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/day02.ipynb#X44sZmlsZQ%3D%3D?line=5'>6</a>         return "오류가 발생했어요!"
# ----> <a href='vscode-notebook-cell:/c%3A/bigdata_git/bigdata_thunder/bigdata1/day02.ipynb#X44sZmlsZQ%3D%3D?line=7'>8</a> raise CustomException
#
# CustomException: 오류가 발생했어요!

# %% [markdown]
# ## 3.6 예외처리
#
# * 예외: 개발자가 직접 처리할 수 있는 코드 내의 문제
# * 오류: 개발자가 처리 불가능한 시스템 상의 오류
# <br>
#
# 예외 처리는 예외의 발생으로 프로그램이 비정상적으로 종료되는 것을 막고
# 사용자에게 발생한 문제에 대한 정보를 전달하기 위함.

# %% [markdown]
# ### 3.6.1 고전적 예외처리
#
# 나누기 프로그램이 있다고 가정.
# 나눗셈은 0으로 나누는 것이 불가능.
# 이 경우, 지금까지 우리가 배운 것을 활용하면 아래와 같은 코드를 작성하게 될 것.
#
# ```python
# a = int(input())
# b = int(input())
#
# if b == 0:
#   print('0으로 나누는 것은 불가능')
# else:
#   print(f'{a}/{b} = {a/b}')
# ```
# 위에서는 if b == 0을 이용해 0으로 나누는 연산을 사용하지 못하도록 처리.
# 하지만 위 방식은 다음과 같은 문제가 존재.
#
# 1. 어떤 문제가 발생할지 예상할 수 있어야 대비 가능
# 2. 어떤 문제가 발생할지 예상 가능하더라도 대비 불가능한 경우 존재
#
# 규모가 작은 프로그램에서는 문제를 예상할 수 있겠지만,
# 규모가 크고 복잡해지면 모든 문제를 예상하는 것이 불가능.
#
# 또한, 문제가 예상 가능하더라도 대비가 힘든 경우가 존재.
# 위에서는 정수가 정상적으로 입력된다는 가정 하에서 int 사용.
# 하지만 입력이 정수가 아니면 문제 발생.

# %% [markdown]
# ### 3.6.2 예외 처리 방식

# %% [markdown]
# #### 모든 예외 처리
# ```python
# try:
#   코드 작성
# except:
#   예외 발생 시 처리 영역
# ```

# %%
try:
    a = int(input())
    b = int(input())

    print(f'{a}/{b} = {a/b}')
except:
    print('error')
# Out:
# error

# %% [markdown]
# #### 특정 예외만 처리
# 위의 예에서는 두 가지 에러가 존재
# 1. 0으로 나누려고 하는 경우
# 2. 정수가 아닌 값을 입력한 경우
#
# 하지만 위의 방식에서는 개별적으로 처리가 불가능.
# 따라서 에러별로 별도의 처리를 해줄 필요가 있을 시 사용.
#
# ```python
# try:
#   코드 작성
# except 에러1:
#   예외 발생 시 처리 영역
# except 에러2:
#   예외 발생 시 처리 영역
# ...
# except Exception:
#   예외 발생 시 처리 영역
# ```

# %%
try:
    a = int(input())
    b = int(input())

    print(f'{a}/{b} = {a/b}')
except ValueError:
    print('문자 입력 불가능')
except ZeroDivisionError:
    print('0으로 나눌 수 없음')
except:
    print('error')
# Out:
# 문자 입력 불가능

# %% [markdown]
# #### 예외 메세지 처리
# 지금까지 모든 예외 메세지를 직접 만들어 사용.
# 하지만 모든 예외는 기본적으로 예외 메세지를 이미 가지고 있음.
# 예외들이 가지고 있는 메세지를 확인하려면 except문에 as절을 추가해서 사용.
#
# ```python
# try:
#   코드 작성
# except 예외 as 예외 메세지:
#   예외 발생 시 처리 영역
# ```

# %%
try:
    a = int(input())
    b = int(input())

    print(f'{a}/{b} = {a/b}')
except ValueError as error:
    print(error)
except ZeroDivisionError as error:
    print(error)
except Exception as error:
    print(error)
# Out:
# invalid literal for int() with base 10: 'd'
